# %%
from moleculekit.molecule import Molecule
from moleculekit.projections.metricrmsd import MetricRmsd
import numpy as np
import os
from torchmdexp.datasets.utils import CA_MAP, CACB_MAP

# %% [markdown]
# ## Create topology

# %%
def pdb2psf_CA(mol, bonds=True, angles=True, dihedrals=True):

    n = mol.numAtoms

    atom_types = []
    for i in range(n):
        atom_types.append(CA_MAP[(mol.resname[i], mol.name[i])])

    if bonds:
        bonds = np.concatenate(
            (
                np.arange(n - 1).reshape([n - 1, 1]),
                (np.arange(1, n).reshape([n - 1, 1])),
            ),
            axis=1,
        )
    else:
        bonds = np.empty([0, 2], dtype=np.int32)

    if angles:
        angles = np.concatenate(
            (
                np.arange(n - 2).reshape([n - 2, 1]),
                (np.arange(1, n - 1).reshape([n - 2, 1])),
                (np.arange(2, n).reshape([n - 2, 1])),
            ),
            axis=1,
        )
    else:
        angles = np.empty([0, 3], dtype=np.int32)

    if dihedrals:

        dihedrals = np.concatenate(
            (
                np.arange(n - 3).reshape([n - 3, 1]),
                (np.arange(1, n - 2).reshape([n - 3, 1])),
                (np.arange(2, n - 1).reshape([n - 3, 1])),
                (np.arange(3, n).reshape([n - 3, 1])),
            ),
            axis = 1,
        )
    else:
        dihedrals = np.empty([0, 4], dtype=np.int32)

    mol.atomtype = np.array(atom_types)
    mol.bonds = bonds
    mol.angles = angles
    mol.dihedrals = dihedrals

    return mol

# %% [markdown]
# ## Write topology

# %%
names = open('/workspace7/torchmd-AD/carles_cath/9b_good.txt')
names = [name.strip() for name in names]

# %%
for name in names:
    i += 1
    pdb = f'/workspace7/torchmd-AD/carles_cath/9b_good_domains/{name}.pdb'
    mol = Molecule(pdb)
    mol.filter('name CA')
    
    # Create topo
    mol_topo = pdb2psf_CA(mol, angles=False)
    psf = f'/workspace7/torchmd-AD/carles_cath/9b_good_topology/{name}.psf'
    mol_topo.write(psf)
# Out:
# 2022-02-02 16:17:42,498 - moleculekit.molecule - INFO - Removed 1247 atoms. 185 atoms remaining in the molecule.
# 2022-02-02 16:17:42,592 - moleculekit.molecule - INFO - Removed 1343 atoms. 208 atoms remaining in the molecule.
# 2022-02-02 16:17:42,745 - moleculekit.molecule - INFO - Removed 2335 atoms. 357 atoms remaining in the molecule.
# 2022-02-02 16:17:42,808 - moleculekit.molecule - INFO - Removed 435 atoms. 63 atoms remaining in the molecule.
# 2022-02-02 16:17:42,886 - moleculekit.molecule - INFO - Removed 609 atoms. 89 atoms remaining in the molecule.
# 2022-02-02 16:17:42,961 - moleculekit.molecule - INFO - Removed 883 atoms. 129 atoms remaining in the molecule.
# 2022-02-02 16:17:43,115 - moleculekit.molecule - INFO - Removed 2789 atoms. 413 atoms remaining in the molecule.
# 2022-02-02 16:17:43,179 - moleculekit.molecule - INFO - Removed 469 atoms. 67 atoms remaining in the molecule.
# 2022-02-02 16:17:43,274 - moleculekit.molecule - INFO - Removed 1263 atoms. 83 atoms remaining in the molecule.
# 2022-02-02 16:17:43,365 - moleculekit.molecule - INFO - Removed 1321 atoms. 208 atoms remaining in the molecule.
# 2022-02-02 16:17:43,583 - moleculekit.molecule - INFO - Removed 2729 atoms. 401 atoms remaining in the molecule.
# 2022-02-02 16:17:43,672 - moleculekit.molecule - INFO - Removed 809 atoms. 119 atoms remaining in the molecule.
# 2022-02-02 16:17:43,740 - moleculekit.molecule - INFO - Removed 777 atoms. 111 atoms remaining in the molecule.
# 2022-02-02 16:17:43,884 - moleculekit.molecule - INFO - Removed 2260 atoms. 342 atoms remaining in the molecule.
# 2022-02-02 16:17:44,033 - moleculekit.molecule - INFO - Removed 2656 atoms. 178 atoms remaining in the molecule.
# 2022-02-02 16:17:44,099 - moleculekit.molecule - INFO - Removed 675 atoms. 89 atoms remaining in the molecule.
# 2022-02-02 16:17:44,184 - moleculekit.molecule - INFO - Removed 1138 atoms. 165 atoms remaining in the molecule.
# 2022-02-02 16:17:44,292 - moleculekit.molecule - INFO - Removed 1224 atoms. 87 atoms remaining in the molecule.
# 2022-02-02 16:17:44,380 - moleculekit.molecule - INFO - Removed 796 atoms. 117 atoms remaining in the molecule.
# 2022-02-02 16:17:44,447 - moleculekit.molecule - INFO - Removed 670 atoms. 106 atoms remaining in the molecule.
# 2022-02-02 16:17:44,507 - moleculekit.molecule - INFO - Removed 576 atoms. 82 atoms remaining in the molecule.
# 2022-02-02 16:17:44,642 - moleculekit.molecule - INFO - Removed 2623 atoms. 180 atoms remaining in the molecule.
# 2022-02-02 16:17:44,737 - moleculekit.molecule - INFO - Removed 1321 atoms. 200 atoms remaining in the molecule.
# 2022-02-02 16:17:44,793 - moleculekit.molecule - INFO - Removed 373 atoms. 50 atoms remaining in the molecule.
# 2022-02-02 16:17:44,876 - moleculekit.molecule - INFO - Removed 818 atoms. 99 atoms remaining in the molecule.
# 2022-02-02 16:17:44,961 - moleculekit.molecule - INFO - Removed 1199 atoms. 174 atoms remaining in the molecule.
# 2022-02-02 16:17:45,080 - moleculekit.molecule - INFO - Removed 1854 atoms. 129 atoms remaining in the molecule.
# 2022-02-02 16:17:45,158 - moleculekit.molecule - INFO - Removed 989 atoms. 150 atoms remaining in the molecule.
# 2022-02-02 16:17:45,232 - moleculekit.molecule - INFO - Removed 639 atoms. 78 atoms remaining in the molecule.
# 2022-02-02 16:17:45,315 - moleculekit.molecule - INFO - Removed 1274 atoms. 83 atoms remaining in the molecule.
# 2022-02-02 16:17:45,444 - moleculekit.molecule - INFO - Removed 1826 atoms. 271 atoms remaining in the molecule.
# 2022-02-02 16:17:45,555 - moleculekit.molecule - INFO - Removed 1777 atoms. 264 atoms remaining in the molecule.
# 2022-02-02 16:17:45,661 - moleculekit.molecule - INFO - Removed 1669 atoms. 195 atoms remaining in the molecule.
# 2022-02-02 16:17:45,728 - moleculekit.molecule - INFO - Removed 639 atoms. 92 atoms remaining in the molecule.
# 2022-02-02 16:17:45,805 - moleculekit.molecule - INFO - Removed 1008 atoms. 153 atoms remaining in the molecule.
# 2022-02-02 16:17:45,888 - moleculekit.molecule - INFO - Removed 575 atoms. 80 atoms remaining in the molecule.
# 2022-02-02 16:17:46,015 - moleculekit.molecule - INFO - Removed 2262 atoms. 319 atoms remaining in the molecule.
# 2022-02-02 16:17:46,105 - moleculekit.molecule - INFO - Removed 821 atoms. 126 atoms remaining in the molecule.
# 2022-02-02 16:17:46,190 - moleculekit.molecule - INFO - Removed 1179 atoms. 170 atoms remaining in the molecule.
# 2022-02-02 16:17:46,298 - moleculekit.molecule - INFO - Removed 1757 atoms. 264 atoms remaining in the molecule.
# 2022-02-02 16:17:46,397 - moleculekit.molecule - INFO - Removed 1479 atoms. 220 atoms remaining in the molecule.
# 2022-02-02 16:17:46,502 - moleculekit.molecule - INFO - Removed 1394 atoms. 199 atoms remaining in the molecule.
# 2022-02-02 16:17:46,556 - moleculekit.molecule - INFO - Removed 416 atoms. 66 atoms remaining in the molecule.
# 2022-02-02 16:17:46,632 - moleculekit.molecule - INFO - Removed 723 atoms. 113 atoms remaining in the molecule.
# 2022-02-02 16:17:46,723 - moleculekit.molecule - INFO - Removed 1381 atoms. 211 atoms remaining in the molecule.
# 2022-02-02 16:17:46,797 - moleculekit.molecule - INFO - Removed 835 atoms. 129 atoms remaining in the molecule.
# 2022-02-02 16:17:46,855 - moleculekit.molecule - INFO - Removed 532 atoms. 75 atoms remaining in the molecule.
# 2022-02-02 16:17:46,938 - moleculekit.molecule - INFO - Removed 1242 atoms. 169 atoms remaining in the molecule.
# 2022-02-02 16:17:47,020 - moleculekit.molecule - INFO - Removed 687 atoms. 109 atoms remaining in the molecule.
# 2022-02-02 16:17:47,095 - moleculekit.molecule - INFO - Removed 645 atoms. 72 atoms remaining in the molecule.
# 2022-02-02 16:17:47,197 - moleculekit.molecule - INFO - Removed 1735 atoms. 210 atoms remaining in the molecule.
# 2022-02-02 16:17:47,304 - moleculekit.molecule - INFO - Removed 1459 atoms. 208 atoms remaining in the molecule.
# 2022-02-02 16:17:47,363 - moleculekit.molecule - INFO - Removed 356 atoms. 54 atoms remaining in the molecule.
# 2022-02-02 16:17:47,449 - moleculekit.molecule - INFO - Removed 597 atoms. 90 atoms remaining in the molecule.
# 2022-02-02 16:17:47,517 - moleculekit.molecule - INFO - Removed 797 atoms. 110 atoms remaining in the molecule.
# 2022-02-02 16:17:47,642 - moleculekit.molecule - INFO - Removed 2189 atoms. 329 atoms remaining in the molecule.
# 2022-02-02 16:17:47,729 - moleculekit.molecule - INFO - Removed 701 atoms. 101 atoms remaining in the molecule.
# 2022-02-02 16:17:47,817 - moleculekit.molecule - INFO - Removed 1202 atoms. 177 atoms remaining in the molecule.
# 2022-02-02 16:17:47,888 - moleculekit.molecule - INFO - Removed 839 atoms. 128 atoms remaining in the molecule.
# 2022-02-02 16:17:47,943 - moleculekit.molecule - INFO - Removed 470 atoms. 67 atoms remaining in the molecule.
# 2022-02-02 16:17:48,013 - moleculekit.molecule - INFO - Removed 747 atoms. 108 atoms remaining in the molecule.
# 2022-02-02 16:17:48,109 - moleculekit.molecule - INFO - Removed 1186 atoms. 167 atoms remaining in the molecule.
# 2022-02-02 16:17:48,198 - moleculekit.molecule - INFO - Removed 411 atoms. 55 atoms remaining in the molecule.
# 2022-02-02 16:17:48,266 - moleculekit.molecule - INFO - Removed 362 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:17:48,318 - moleculekit.molecule - INFO - Removed 458 atoms. 63 atoms remaining in the molecule.
# 2022-02-02 16:17:48,392 - moleculekit.molecule - INFO - Removed 978 atoms. 147 atoms remaining in the molecule.
# 2022-02-02 16:17:48,446 - moleculekit.molecule - INFO - Removed 423 atoms. 61 atoms remaining in the molecule.
# 2022-02-02 16:17:48,520 - moleculekit.molecule - INFO - Removed 1034 atoms. 80 atoms remaining in the molecule.
# 2022-02-02 16:17:48,625 - moleculekit.molecule - INFO - Removed 1730 atoms. 241 atoms remaining in the molecule.
# 2022-02-02 16:17:48,688 - moleculekit.molecule - INFO - Removed 576 atoms. 87 atoms remaining in the molecule.
# 2022-02-02 16:17:48,800 - moleculekit.molecule - INFO - Removed 1841 atoms. 275 atoms remaining in the molecule.
# 2022-02-02 16:17:48,929 - moleculekit.molecule - INFO - Removed 2295 atoms. 159 atoms remaining in the molecule.
# 2022-02-02 16:17:49,018 - moleculekit.molecule - INFO - Removed 938 atoms. 139 atoms remaining in the molecule.
# 2022-02-02 16:17:49,090 - moleculekit.molecule - INFO - Removed 902 atoms. 53 atoms remaining in the molecule.
# 2022-02-02 16:17:49,235 - moleculekit.molecule - INFO - Removed 2403 atoms. 347 atoms remaining in the molecule.
# 2022-02-02 16:17:49,318 - moleculekit.molecule - INFO - Removed 1121 atoms. 69 atoms remaining in the molecule.
# 2022-02-02 16:17:49,386 - moleculekit.molecule - INFO - Removed 728 atoms. 110 atoms remaining in the molecule.
# 2022-02-02 16:17:49,437 - moleculekit.molecule - INFO - Removed 384 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:17:49,531 - moleculekit.molecule - INFO - Removed 1052 atoms. 123 atoms remaining in the molecule.
# 2022-02-02 16:17:49,620 - moleculekit.molecule - INFO - Removed 1334 atoms. 156 atoms remaining in the molecule.
# 2022-02-02 16:17:49,685 - moleculekit.molecule - INFO - Removed 619 atoms. 98 atoms remaining in the molecule.
# 2022-02-02 16:17:49,768 - moleculekit.molecule - INFO - Removed 1053 atoms. 162 atoms remaining in the molecule.
# 2022-02-02 16:17:49,935 - moleculekit.molecule - INFO - Removed 3185 atoms. 474 atoms remaining in the molecule.
# 2022-02-02 16:17:50,030 - moleculekit.molecule - INFO - Removed 747 atoms. 114 atoms remaining in the molecule.
# 2022-02-02 16:17:50,116 - moleculekit.molecule - INFO - Removed 1212 atoms. 192 atoms remaining in the molecule.
# 2022-02-02 16:17:50,217 - moleculekit.molecule - INFO - Removed 1483 atoms. 214 atoms remaining in the molecule.
# 2022-02-02 16:17:50,333 - moleculekit.molecule - INFO - Removed 1867 atoms. 289 atoms remaining in the molecule.
# 2022-02-02 16:17:50,443 - moleculekit.molecule - INFO - Removed 1345 atoms. 102 atoms remaining in the molecule.
# 2022-02-02 16:17:50,551 - moleculekit.molecule - INFO - Removed 1453 atoms. 206 atoms remaining in the molecule.
# 2022-02-02 16:17:50,627 - moleculekit.molecule - INFO - Removed 723 atoms. 106 atoms remaining in the molecule.
# 2022-02-02 16:17:50,693 - moleculekit.molecule - INFO - Removed 717 atoms. 110 atoms remaining in the molecule.
# 2022-02-02 16:17:50,796 - moleculekit.molecule - INFO - Removed 667 atoms. 104 atoms remaining in the molecule.
# 2022-02-02 16:17:50,922 - moleculekit.molecule - INFO - Removed 1762 atoms. 263 atoms remaining in the molecule.
# 2022-02-02 16:17:50,988 - moleculekit.molecule - INFO - Removed 616 atoms. 95 atoms remaining in the molecule.
# 2022-02-02 16:17:51,096 - moleculekit.molecule - INFO - Removed 1772 atoms. 256 atoms remaining in the molecule.
# 2022-02-02 16:17:51,155 - moleculekit.molecule - INFO - Removed 448 atoms. 60 atoms remaining in the molecule.
# 2022-02-02 16:17:51,231 - moleculekit.molecule - INFO - Removed 602 atoms. 83 atoms remaining in the molecule.
# 2022-02-02 16:17:51,333 - moleculekit.molecule - INFO - Removed 1218 atoms. 180 atoms remaining in the molecule.
# 2022-02-02 16:17:51,399 - moleculekit.molecule - INFO - Removed 734 atoms. 104 atoms remaining in the molecule.
# 2022-02-02 16:17:51,482 - moleculekit.molecule - INFO - Removed 1130 atoms. 167 atoms remaining in the molecule.
# 2022-02-02 16:17:51,560 - moleculekit.molecule - INFO - Removed 1004 atoms. 144 atoms remaining in the molecule.
# 2022-02-02 16:17:51,613 - moleculekit.molecule - INFO - Removed 399 atoms. 56 atoms remaining in the molecule.
# 2022-02-02 16:17:51,701 - moleculekit.molecule - INFO - Removed 991 atoms. 73 atoms remaining in the molecule.
# 2022-02-02 16:17:51,843 - moleculekit.molecule - INFO - Removed 2284 atoms. 340 atoms remaining in the molecule.
# 2022-02-02 16:17:51,954 - moleculekit.molecule - INFO - Removed 1736 atoms. 251 atoms remaining in the molecule.
# 2022-02-02 16:17:52,084 - moleculekit.molecule - INFO - Removed 1848 atoms. 138 atoms remaining in the molecule.
# 2022-02-02 16:17:52,171 - moleculekit.molecule - INFO - Removed 1202 atoms. 175 atoms remaining in the molecule.
# 2022-02-02 16:17:52,257 - moleculekit.molecule - INFO - Removed 1070 atoms. 66 atoms remaining in the molecule.
# 2022-02-02 16:17:52,402 - moleculekit.molecule - INFO - Removed 2380 atoms. 348 atoms remaining in the molecule.
# 2022-02-02 16:17:52,509 - moleculekit.molecule - INFO - Removed 1005 atoms. 138 atoms remaining in the molecule.
# 2022-02-02 16:17:52,593 - moleculekit.molecule - INFO - Removed 942 atoms. 140 atoms remaining in the molecule.
# 2022-02-02 16:17:52,707 - moleculekit.molecule - INFO - Removed 1883 atoms. 285 atoms remaining in the molecule.
# 2022-02-02 16:17:52,807 - moleculekit.molecule - INFO - Removed 1386 atoms. 97 atoms remaining in the molecule.
# 2022-02-02 16:17:52,903 - moleculekit.molecule - INFO - Removed 1501 atoms. 215 atoms remaining in the molecule.
# 2022-02-02 16:17:52,981 - moleculekit.molecule - INFO - Removed 1014 atoms. 76 atoms remaining in the molecule.
# 2022-02-02 16:17:53,074 - moleculekit.molecule - INFO - Removed 1165 atoms. 163 atoms remaining in the molecule.
# 2022-02-02 16:17:53,190 - moleculekit.molecule - INFO - Removed 1751 atoms. 265 atoms remaining in the molecule.
# 2022-02-02 16:17:53,254 - moleculekit.molecule - INFO - Removed 542 atoms. 78 atoms remaining in the molecule.
# 2022-02-02 16:17:53,364 - moleculekit.molecule - INFO - Removed 1796 atoms. 284 atoms remaining in the molecule.
# 2022-02-02 16:17:53,535 - moleculekit.molecule - INFO - Removed 1595 atoms. 108 atoms remaining in the molecule.
# 2022-02-02 16:17:53,596 - moleculekit.molecule - INFO - Removed 596 atoms. 95 atoms remaining in the molecule.
# 2022-02-02 16:17:53,655 - moleculekit.molecule - INFO - Removed 567 atoms. 88 atoms remaining in the molecule.
# 2022-02-02 16:17:53,731 - moleculekit.molecule - INFO - Removed 983 atoms. 142 atoms remaining in the molecule.
# 2022-02-02 16:17:53,802 - moleculekit.molecule - INFO - Removed 785 atoms. 127 atoms remaining in the molecule.
# 2022-02-02 16:17:53,869 - moleculekit.molecule - INFO - Removed 425 atoms. 66 atoms remaining in the molecule.
# 2022-02-02 16:17:54,037 - moleculekit.molecule - INFO - Removed 3428 atoms. 484 atoms remaining in the molecule.
# 2022-02-02 16:17:54,135 - moleculekit.molecule - INFO - Removed 1364 atoms. 191 atoms remaining in the molecule.
# 2022-02-02 16:17:54,209 - moleculekit.molecule - INFO - Removed 709 atoms. 106 atoms remaining in the molecule.
# 2022-02-02 16:17:54,357 - moleculekit.molecule - INFO - Removed 2876 atoms. 401 atoms remaining in the molecule.
# 2022-02-02 16:17:54,497 - moleculekit.molecule - INFO - Removed 2227 atoms. 312 atoms remaining in the molecule.
# 2022-02-02 16:17:54,583 - moleculekit.molecule - INFO - Removed 813 atoms. 121 atoms remaining in the molecule.
# 2022-02-02 16:17:54,645 - moleculekit.molecule - INFO - Removed 665 atoms. 93 atoms remaining in the molecule.
# 2022-02-02 16:17:54,712 - moleculekit.molecule - INFO - Removed 716 atoms. 107 atoms remaining in the molecule.
# 2022-02-02 16:17:54,778 - moleculekit.molecule - INFO - Removed 730 atoms. 54 atoms remaining in the molecule.
# 2022-02-02 16:17:54,846 - moleculekit.molecule - INFO - Removed 835 atoms. 59 atoms remaining in the molecule.
# 2022-02-02 16:17:54,915 - moleculekit.molecule - INFO - Removed 803 atoms. 51 atoms remaining in the molecule.
# 2022-02-02 16:17:54,977 - moleculekit.molecule - INFO - Removed 458 atoms. 67 atoms remaining in the molecule.
# 2022-02-02 16:17:55,047 - moleculekit.molecule - INFO - Removed 576 atoms. 82 atoms remaining in the molecule.
# 2022-02-02 16:17:55,133 - moleculekit.molecule - INFO - Removed 751 atoms. 106 atoms remaining in the molecule.
# 2022-02-02 16:17:55,252 - moleculekit.molecule - INFO - Removed 1887 atoms. 135 atoms remaining in the molecule.
# 2022-02-02 16:17:55,313 - moleculekit.molecule - INFO - Removed 602 atoms. 94 atoms remaining in the molecule.
# 2022-02-02 16:17:55,377 - moleculekit.molecule - INFO - Removed 715 atoms. 103 atoms remaining in the molecule.
# 2022-02-02 16:17:55,430 - moleculekit.molecule - INFO - Removed 438 atoms. 64 atoms remaining in the molecule.
# 2022-02-02 16:17:55,534 - moleculekit.molecule - INFO - Removed 1472 atoms. 213 atoms remaining in the molecule.
# 2022-02-02 16:17:55,634 - moleculekit.molecule - INFO - Removed 1514 atoms. 177 atoms remaining in the molecule.
# 2022-02-02 16:17:55,707 - moleculekit.molecule - INFO - Removed 857 atoms. 126 atoms remaining in the molecule.
# 2022-02-02 16:17:55,769 - moleculekit.molecule - INFO - Removed 577 atoms. 83 atoms remaining in the molecule.
# 2022-02-02 16:17:55,854 - moleculekit.molecule - INFO - Removed 1168 atoms. 175 atoms remaining in the molecule.
# 2022-02-02 16:17:55,932 - moleculekit.molecule - INFO - Removed 698 atoms. 84 atoms remaining in the molecule.
# 2022-02-02 16:17:56,033 - moleculekit.molecule - INFO - Removed 1298 atoms. 151 atoms remaining in the molecule.
# 2022-02-02 16:17:56,151 - moleculekit.molecule - INFO - Removed 2005 atoms. 298 atoms remaining in the molecule.
# 2022-02-02 16:17:56,226 - moleculekit.molecule - INFO - Removed 790 atoms. 129 atoms remaining in the molecule.
# 2022-02-02 16:17:56,283 - moleculekit.molecule - INFO - Removed 474 atoms. 72 atoms remaining in the molecule.
# 2022-02-02 16:17:56,378 - moleculekit.molecule - INFO - Removed 1463 atoms. 224 atoms remaining in the molecule.
# 2022-02-02 16:17:56,449 - moleculekit.molecule - INFO - Removed 544 atoms. 80 atoms remaining in the molecule.
# 2022-02-02 16:17:56,564 - moleculekit.molecule - INFO - Removed 1955 atoms. 279 atoms remaining in the molecule.
# 2022-02-02 16:17:56,636 - moleculekit.molecule - INFO - Removed 419 atoms. 68 atoms remaining in the molecule.
# 2022-02-02 16:17:56,713 - moleculekit.molecule - INFO - Removed 741 atoms. 115 atoms remaining in the molecule.
# 2022-02-02 16:17:56,769 - moleculekit.molecule - INFO - Removed 459 atoms. 66 atoms remaining in the molecule.
# 2022-02-02 16:17:56,855 - moleculekit.molecule - INFO - Removed 1214 atoms. 173 atoms remaining in the molecule.
# 2022-02-02 16:17:56,928 - moleculekit.molecule - INFO - Removed 602 atoms. 86 atoms remaining in the molecule.
# 2022-02-02 16:17:56,987 - moleculekit.molecule - INFO - Removed 525 atoms. 84 atoms remaining in the molecule.
# 2022-02-02 16:17:57,069 - moleculekit.molecule - INFO - Removed 1080 atoms. 159 atoms remaining in the molecule.
# 2022-02-02 16:17:57,151 - moleculekit.molecule - INFO - Removed 1109 atoms. 158 atoms remaining in the molecule.
# 2022-02-02 16:17:57,208 - moleculekit.molecule - INFO - Removed 429 atoms. 60 atoms remaining in the molecule.
# 2022-02-02 16:17:57,261 - moleculekit.molecule - INFO - Removed 423 atoms. 61 atoms remaining in the molecule.
# 2022-02-02 16:17:57,341 - moleculekit.molecule - INFO - Removed 1177 atoms. 83 atoms remaining in the molecule.
# 2022-02-02 16:17:57,447 - moleculekit.molecule - INFO - Removed 1647 atoms. 243 atoms remaining in the molecule.
# 2022-02-02 16:17:57,507 - moleculekit.molecule - INFO - Removed 470 atoms. 67 atoms remaining in the molecule.
# 2022-02-02 16:17:57,593 - moleculekit.molecule - INFO - Removed 1225 atoms. 185 atoms remaining in the molecule.
# 2022-02-02 16:17:57,679 - moleculekit.molecule - INFO - Removed 1109 atoms. 159 atoms remaining in the molecule.
# 2022-02-02 16:17:57,777 - moleculekit.molecule - INFO - Removed 1255 atoms. 81 atoms remaining in the molecule.
# 2022-02-02 16:17:57,828 - moleculekit.molecule - INFO - Removed 345 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:17:57,884 - moleculekit.molecule - INFO - Removed 503 atoms. 75 atoms remaining in the molecule.
# 2022-02-02 16:17:57,936 - moleculekit.molecule - INFO - Removed 396 atoms. 59 atoms remaining in the molecule.
# 2022-02-02 16:17:58,005 - moleculekit.molecule - INFO - Removed 435 atoms. 64 atoms remaining in the molecule.
# 2022-02-02 16:17:58,115 - moleculekit.molecule - INFO - Removed 1560 atoms. 237 atoms remaining in the molecule.
# 2022-02-02 16:17:58,205 - moleculekit.molecule - INFO - Removed 1327 atoms. 89 atoms remaining in the molecule.
# 2022-02-02 16:17:58,270 - moleculekit.molecule - INFO - Removed 497 atoms. 69 atoms remaining in the molecule.
# 2022-02-02 16:17:58,327 - moleculekit.molecule - INFO - Removed 534 atoms. 76 atoms remaining in the molecule.
# 2022-02-02 16:17:58,384 - moleculekit.molecule - INFO - Removed 534 atoms. 79 atoms remaining in the molecule.
# 2022-02-02 16:17:58,524 - moleculekit.molecule - INFO - Removed 2654 atoms. 384 atoms remaining in the molecule.
# 2022-02-02 16:17:58,583 - moleculekit.molecule - INFO - Removed 390 atoms. 52 atoms remaining in the molecule.
# 2022-02-02 16:17:58,644 - moleculekit.molecule - INFO - Removed 355 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:17:58,706 - moleculekit.molecule - INFO - Removed 408 atoms. 68 atoms remaining in the molecule.
# 2022-02-02 16:17:58,801 - moleculekit.molecule - INFO - Removed 1398 atoms. 201 atoms remaining in the molecule.
# 2022-02-02 16:17:58,866 - moleculekit.molecule - INFO - Removed 615 atoms. 90 atoms remaining in the molecule.
# 2022-02-02 16:17:58,920 - moleculekit.molecule - INFO - Removed 478 atoms. 66 atoms remaining in the molecule.
# 2022-02-02 16:17:58,984 - moleculekit.molecule - INFO - Removed 703 atoms. 104 atoms remaining in the molecule.
# 2022-02-02 16:17:59,091 - moleculekit.molecule - INFO - Removed 1668 atoms. 237 atoms remaining in the molecule.
# 2022-02-02 16:17:59,222 - moleculekit.molecule - INFO - Removed 2390 atoms. 158 atoms remaining in the molecule.
# 2022-02-02 16:17:59,278 - moleculekit.molecule - INFO - Removed 378 atoms. 56 atoms remaining in the molecule.
# 2022-02-02 16:17:59,341 - moleculekit.molecule - INFO - Removed 548 atoms. 76 atoms remaining in the molecule.
# 2022-02-02 16:17:59,473 - moleculekit.molecule - INFO - Removed 1565 atoms. 243 atoms remaining in the molecule.
# 2022-02-02 16:17:59,624 - moleculekit.molecule - INFO - Removed 2121 atoms. 309 atoms remaining in the molecule.
# 2022-02-02 16:17:59,684 - moleculekit.molecule - INFO - Removed 425 atoms. 60 atoms remaining in the molecule.
# 2022-02-02 16:17:59,762 - moleculekit.molecule - INFO - Removed 1055 atoms. 73 atoms remaining in the molecule.
# 2022-02-02 16:17:59,840 - moleculekit.molecule - INFO - Removed 951 atoms. 134 atoms remaining in the molecule.
# 2022-02-02 16:17:59,965 - moleculekit.molecule - INFO - Removed 2158 atoms. 323 atoms remaining in the molecule.
# 2022-02-02 16:18:00,035 - moleculekit.molecule - INFO - Removed 656 atoms. 87 atoms remaining in the molecule.
# 2022-02-02 16:18:00,088 - moleculekit.molecule - INFO - Removed 411 atoms. 61 atoms remaining in the molecule.
# 2022-02-02 16:18:00,164 - moleculekit.molecule - INFO - Removed 750 atoms. 102 atoms remaining in the molecule.
# 2022-02-02 16:18:00,260 - moleculekit.molecule - INFO - Removed 1337 atoms. 206 atoms remaining in the molecule.
# 2022-02-02 16:18:00,354 - moleculekit.molecule - INFO - Removed 1151 atoms. 80 atoms remaining in the molecule.
# 2022-02-02 16:18:00,419 - moleculekit.molecule - INFO - Removed 682 atoms. 112 atoms remaining in the molecule.
# 2022-02-02 16:18:00,488 - moleculekit.molecule - INFO - Removed 841 atoms. 127 atoms remaining in the molecule.
# 2022-02-02 16:18:00,572 - moleculekit.molecule - INFO - Removed 1149 atoms. 168 atoms remaining in the molecule.
# 2022-02-02 16:18:00,657 - moleculekit.molecule - INFO - Removed 1150 atoms. 168 atoms remaining in the molecule.
# 2022-02-02 16:18:00,717 - moleculekit.molecule - INFO - Removed 534 atoms. 73 atoms remaining in the molecule.
# 2022-02-02 16:18:00,813 - moleculekit.molecule - INFO - Removed 1381 atoms. 206 atoms remaining in the molecule.
# 2022-02-02 16:18:00,879 - moleculekit.molecule - INFO - Removed 442 atoms. 61 atoms remaining in the molecule.
# 2022-02-02 16:18:00,975 - moleculekit.molecule - INFO - Removed 1586 atoms. 104 atoms remaining in the molecule.
# 2022-02-02 16:18:01,064 - moleculekit.molecule - INFO - Removed 1272 atoms. 185 atoms remaining in the molecule.
# 2022-02-02 16:18:01,236 - moleculekit.molecule - INFO - Removed 2962 atoms. 432 atoms remaining in the molecule.
# 2022-02-02 16:18:01,296 - moleculekit.molecule - INFO - Removed 374 atoms. 60 atoms remaining in the molecule.
# 2022-02-02 16:18:01,362 - moleculekit.molecule - INFO - Removed 819 atoms. 59 atoms remaining in the molecule.
# 2022-02-02 16:18:01,443 - moleculekit.molecule - INFO - Removed 1131 atoms. 183 atoms remaining in the molecule.
# 2022-02-02 16:18:01,541 - moleculekit.molecule - INFO - Removed 1504 atoms. 230 atoms remaining in the molecule.
# 2022-02-02 16:18:01,596 - moleculekit.molecule - INFO - Removed 398 atoms. 55 atoms remaining in the molecule.
# 2022-02-02 16:18:01,707 - moleculekit.molecule - INFO - Removed 1827 atoms. 254 atoms remaining in the molecule.
# 2022-02-02 16:18:01,772 - moleculekit.molecule - INFO - Removed 378 atoms. 53 atoms remaining in the molecule.
# 2022-02-02 16:18:01,844 - moleculekit.molecule - INFO - Removed 671 atoms. 50 atoms remaining in the molecule.
# 2022-02-02 16:18:02,001 - moleculekit.molecule - INFO - Removed 2999 atoms. 446 atoms remaining in the molecule.
# 2022-02-02 16:18:02,075 - moleculekit.molecule - INFO - Removed 722 atoms. 106 atoms remaining in the molecule.
# 2022-02-02 16:18:02,155 - moleculekit.molecule - INFO - Removed 796 atoms. 113 atoms remaining in the molecule.
# 2022-02-02 16:18:02,289 - moleculekit.molecule - INFO - Removed 2394 atoms. 358 atoms remaining in the molecule.
# 2022-02-02 16:18:02,400 - moleculekit.molecule - INFO - Removed 1763 atoms. 267 atoms remaining in the molecule.
# 2022-02-02 16:18:02,488 - moleculekit.molecule - INFO - Removed 1153 atoms. 177 atoms remaining in the molecule.
# 2022-02-02 16:18:02,560 - moleculekit.molecule - INFO - Removed 825 atoms. 120 atoms remaining in the molecule.
# 2022-02-02 16:18:02,710 - moleculekit.molecule - INFO - Removed 2655 atoms. 380 atoms remaining in the molecule.
# 2022-02-02 16:18:02,774 - moleculekit.molecule - INFO - Removed 510 atoms. 76 atoms remaining in the molecule.
# 2022-02-02 16:18:02,855 - moleculekit.molecule - INFO - Removed 1125 atoms. 166 atoms remaining in the molecule.
# 2022-02-02 16:18:02,918 - moleculekit.molecule - INFO - Removed 600 atoms. 91 atoms remaining in the molecule.
# 2022-02-02 16:18:02,986 - moleculekit.molecule - INFO - Removed 794 atoms. 126 atoms remaining in the molecule.
# 2022-02-02 16:18:03,153 - moleculekit.molecule - INFO - Removed 1580 atoms. 246 atoms remaining in the molecule.
# 2022-02-02 16:18:03,217 - moleculekit.molecule - INFO - Removed 578 atoms. 82 atoms remaining in the molecule.
# 2022-02-02 16:18:03,274 - moleculekit.molecule - INFO - Removed 467 atoms. 68 atoms remaining in the molecule.
# 2022-02-02 16:18:03,348 - moleculekit.molecule - INFO - Removed 988 atoms. 143 atoms remaining in the molecule.
# 2022-02-02 16:18:03,406 - moleculekit.molecule - INFO - Removed 530 atoms. 82 atoms remaining in the molecule.
# 2022-02-02 16:18:03,472 - moleculekit.molecule - INFO - Removed 742 atoms. 111 atoms remaining in the molecule.
# 2022-02-02 16:18:03,534 - moleculekit.molecule - INFO - Removed 618 atoms. 95 atoms remaining in the molecule.
# 2022-02-02 16:18:03,636 - moleculekit.molecule - INFO - Removed 1615 atoms. 254 atoms remaining in the molecule.
# 2022-02-02 16:18:03,692 - moleculekit.molecule - INFO - Removed 352 atoms. 52 atoms remaining in the molecule.
# 2022-02-02 16:18:03,802 - moleculekit.molecule - INFO - Removed 1753 atoms. 264 atoms remaining in the molecule.
# 2022-02-02 16:18:03,858 - moleculekit.molecule - INFO - Removed 387 atoms. 56 atoms remaining in the molecule.
# 2022-02-02 16:18:03,938 - moleculekit.molecule - INFO - Removed 1207 atoms. 77 atoms remaining in the molecule.
# 2022-02-02 16:18:04,084 - moleculekit.molecule - INFO - Removed 2514 atoms. 353 atoms remaining in the molecule.
# 2022-02-02 16:18:04,163 - moleculekit.molecule - INFO - Removed 686 atoms. 82 atoms remaining in the molecule.
# 2022-02-02 16:18:04,252 - moleculekit.molecule - INFO - Removed 1299 atoms. 189 atoms remaining in the molecule.
# 2022-02-02 16:18:04,369 - moleculekit.molecule - INFO - Removed 1993 atoms. 302 atoms remaining in the molecule.
# 2022-02-02 16:18:04,449 - moleculekit.molecule - INFO - Removed 985 atoms. 150 atoms remaining in the molecule.
# 2022-02-02 16:18:04,628 - moleculekit.molecule - INFO - Removed 3564 atoms. 500 atoms remaining in the molecule.
# 2022-02-02 16:18:04,715 - moleculekit.molecule - INFO - Removed 781 atoms. 117 atoms remaining in the molecule.
# 2022-02-02 16:18:04,792 - moleculekit.molecule - INFO - Removed 948 atoms. 134 atoms remaining in the molecule.
# 2022-02-02 16:18:04,943 - moleculekit.molecule - INFO - Removed 2875 atoms. 338 atoms remaining in the molecule.
# 2022-02-02 16:18:05,011 - moleculekit.molecule - INFO - Removed 575 atoms. 80 atoms remaining in the molecule.
# 2022-02-02 16:18:05,104 - moleculekit.molecule - INFO - Removed 1353 atoms. 213 atoms remaining in the molecule.
# 2022-02-02 16:18:05,174 - moleculekit.molecule - INFO - Removed 753 atoms. 105 atoms remaining in the molecule.
# 2022-02-02 16:18:05,307 - moleculekit.molecule - INFO - Removed 2083 atoms. 289 atoms remaining in the molecule.
# 2022-02-02 16:18:05,396 - moleculekit.molecule - INFO - Removed 1164 atoms. 171 atoms remaining in the molecule.
# 2022-02-02 16:18:05,482 - moleculekit.molecule - INFO - Removed 1115 atoms. 156 atoms remaining in the molecule.
# 2022-02-02 16:18:05,538 - moleculekit.molecule - INFO - Removed 410 atoms. 62 atoms remaining in the molecule.
# 2022-02-02 16:18:05,588 - moleculekit.molecule - INFO - Removed 384 atoms. 52 atoms remaining in the molecule.
# 2022-02-02 16:18:05,648 - moleculekit.molecule - INFO - Removed 560 atoms. 89 atoms remaining in the molecule.
# 2022-02-02 16:18:05,714 - moleculekit.molecule - INFO - Removed 428 atoms. 66 atoms remaining in the molecule.
# 2022-02-02 16:18:05,794 - moleculekit.molecule - INFO - Removed 1019 atoms. 145 atoms remaining in the molecule.
# 2022-02-02 16:18:05,875 - moleculekit.molecule - INFO - Removed 1085 atoms. 163 atoms remaining in the molecule.
# 2022-02-02 16:18:05,946 - moleculekit.molecule - INFO - Removed 616 atoms. 85 atoms remaining in the molecule.
# 2022-02-02 16:18:06,024 - moleculekit.molecule - INFO - Removed 949 atoms. 153 atoms remaining in the molecule.
# 2022-02-02 16:18:06,153 - moleculekit.molecule - INFO - Removed 1932 atoms. 275 atoms remaining in the molecule.
# 2022-02-02 16:18:06,215 - moleculekit.molecule - INFO - Removed 493 atoms. 70 atoms remaining in the molecule.
# 2022-02-02 16:18:06,297 - moleculekit.molecule - INFO - Removed 1046 atoms. 158 atoms remaining in the molecule.
# 2022-02-02 16:18:06,373 - moleculekit.molecule - INFO - Removed 957 atoms. 140 atoms remaining in the molecule.
# 2022-02-02 16:18:06,448 - moleculekit.molecule - INFO - Removed 945 atoms. 65 atoms remaining in the molecule.
# 2022-02-02 16:18:06,534 - moleculekit.molecule - INFO - Removed 1228 atoms. 84 atoms remaining in the molecule.
# 2022-02-02 16:18:06,596 - moleculekit.molecule - INFO - Removed 613 atoms. 90 atoms remaining in the molecule.
# 2022-02-02 16:18:06,685 - moleculekit.molecule - INFO - Removed 867 atoms. 125 atoms remaining in the molecule.
# 2022-02-02 16:18:06,764 - moleculekit.molecule - INFO - Removed 924 atoms. 134 atoms remaining in the molecule.
# 2022-02-02 16:18:06,885 - moleculekit.molecule - INFO - Removed 2052 atoms. 311 atoms remaining in the molecule.
# 2022-02-02 16:18:06,973 - moleculekit.molecule - INFO - Removed 1112 atoms. 156 atoms remaining in the molecule.
# 2022-02-02 16:18:07,029 - moleculekit.molecule - INFO - Removed 411 atoms. 60 atoms remaining in the molecule.
# 2022-02-02 16:18:07,087 - moleculekit.molecule - INFO - Removed 492 atoms. 74 atoms remaining in the molecule.
# 2022-02-02 16:18:07,151 - moleculekit.molecule - INFO - Removed 683 atoms. 100 atoms remaining in the molecule.
# 2022-02-02 16:18:07,214 - moleculekit.molecule - INFO - Removed 445 atoms. 68 atoms remaining in the molecule.
# 2022-02-02 16:18:07,276 - moleculekit.molecule - INFO - Removed 595 atoms. 87 atoms remaining in the molecule.
# 2022-02-02 16:18:07,340 - moleculekit.molecule - INFO - Removed 740 atoms. 114 atoms remaining in the molecule.
# 2022-02-02 16:18:07,408 - moleculekit.molecule - INFO - Removed 741 atoms. 105 atoms remaining in the molecule.
# 2022-02-02 16:18:07,523 - moleculekit.molecule - INFO - Removed 1947 atoms. 272 atoms remaining in the molecule.
# 2022-02-02 16:18:07,603 - moleculekit.molecule - INFO - Removed 984 atoms. 144 atoms remaining in the molecule.
# 2022-02-02 16:18:07,711 - moleculekit.molecule - INFO - Removed 1842 atoms. 119 atoms remaining in the molecule.
# 2022-02-02 16:18:07,784 - moleculekit.molecule - INFO - Removed 845 atoms. 52 atoms remaining in the molecule.
# 2022-02-02 16:18:07,851 - moleculekit.molecule - INFO - Removed 718 atoms. 106 atoms remaining in the molecule.
# 2022-02-02 16:18:07,918 - moleculekit.molecule - INFO - Removed 748 atoms. 105 atoms remaining in the molecule.
# 2022-02-02 16:18:08,067 - moleculekit.molecule - INFO - Removed 2476 atoms. 342 atoms remaining in the molecule.
# 2022-02-02 16:18:08,159 - moleculekit.molecule - INFO - Removed 1209 atoms. 179 atoms remaining in the molecule.
# 2022-02-02 16:18:08,247 - moleculekit.molecule - INFO - Removed 1148 atoms. 163 atoms remaining in the molecule.
# 2022-02-02 16:18:08,377 - moleculekit.molecule - INFO - Removed 2255 atoms. 334 atoms remaining in the molecule.
# 2022-02-02 16:18:08,481 - moleculekit.molecule - INFO - Removed 1441 atoms. 210 atoms remaining in the molecule.
# 2022-02-02 16:18:08,582 - moleculekit.molecule - INFO - Removed 1460 atoms. 209 atoms remaining in the molecule.
# 2022-02-02 16:18:08,658 - moleculekit.molecule - INFO - Removed 624 atoms. 87 atoms remaining in the molecule.
# 2022-02-02 16:18:08,809 - moleculekit.molecule - INFO - Removed 2863 atoms. 402 atoms remaining in the molecule.
# 2022-02-02 16:18:08,903 - moleculekit.molecule - INFO - Removed 1221 atoms. 178 atoms remaining in the molecule.
# 2022-02-02 16:18:08,964 - moleculekit.molecule - INFO - Removed 580 atoms. 88 atoms remaining in the molecule.
# 2022-02-02 16:18:09,043 - moleculekit.molecule - INFO - Removed 972 atoms. 138 atoms remaining in the molecule.
# 2022-02-02 16:18:09,101 - moleculekit.molecule - INFO - Removed 529 atoms. 79 atoms remaining in the molecule.
# 2022-02-02 16:18:09,205 - moleculekit.molecule - INFO - Removed 1695 atoms. 251 atoms remaining in the molecule.
# 2022-02-02 16:18:09,271 - moleculekit.molecule - INFO - Removed 434 atoms. 52 atoms remaining in the molecule.
# 2022-02-02 16:18:09,431 - moleculekit.molecule - INFO - Removed 3194 atoms. 467 atoms remaining in the molecule.
# 2022-02-02 16:18:09,507 - moleculekit.molecule - INFO - Removed 777 atoms. 111 atoms remaining in the molecule.
# 2022-02-02 16:18:09,594 - moleculekit.molecule - INFO - Removed 1025 atoms. 149 atoms remaining in the molecule.
# 2022-02-02 16:18:09,652 - moleculekit.molecule - INFO - Removed 509 atoms. 80 atoms remaining in the molecule.
# 2022-02-02 16:18:09,739 - moleculekit.molecule - INFO - Removed 920 atoms. 129 atoms remaining in the molecule.
# 2022-02-02 16:18:09,876 - moleculekit.molecule - INFO - Removed 2434 atoms. 357 atoms remaining in the molecule.
# 2022-02-02 16:18:09,964 - moleculekit.molecule - INFO - Removed 1104 atoms. 167 atoms remaining in the molecule.
# 2022-02-02 16:18:10,057 - moleculekit.molecule - INFO - Removed 1351 atoms. 89 atoms remaining in the molecule.
# 2022-02-02 16:18:10,184 - moleculekit.molecule - INFO - Removed 1281 atoms. 86 atoms remaining in the molecule.
# 2022-02-02 16:18:10,281 - moleculekit.molecule - INFO - Removed 1490 atoms. 221 atoms remaining in the molecule.
# 2022-02-02 16:18:10,369 - moleculekit.molecule - INFO - Removed 1302 atoms. 204 atoms remaining in the molecule.
# 2022-02-02 16:18:10,439 - moleculekit.molecule - INFO - Removed 791 atoms. 108 atoms remaining in the molecule.
# 2022-02-02 16:18:10,549 - moleculekit.molecule - INFO - Removed 1883 atoms. 284 atoms remaining in the molecule.
# 2022-02-02 16:18:10,641 - moleculekit.molecule - INFO - Removed 1004 atoms. 141 atoms remaining in the molecule.
# 2022-02-02 16:18:10,721 - moleculekit.molecule - INFO - Removed 840 atoms. 122 atoms remaining in the molecule.
# 2022-02-02 16:18:10,800 - moleculekit.molecule - INFO - Removed 977 atoms. 135 atoms remaining in the molecule.
# 2022-02-02 16:18:10,867 - moleculekit.molecule - INFO - Removed 770 atoms. 116 atoms remaining in the molecule.
# 2022-02-02 16:18:10,964 - moleculekit.molecule - INFO - Removed 1645 atoms. 113 atoms remaining in the molecule.
# 2022-02-02 16:18:11,041 - moleculekit.molecule - INFO - Removed 1014 atoms. 137 atoms remaining in the molecule.
# 2022-02-02 16:18:11,096 - moleculekit.molecule - INFO - Removed 348 atoms. 50 atoms remaining in the molecule.
# 2022-02-02 16:18:11,166 - moleculekit.molecule - INFO - Removed 528 atoms. 73 atoms remaining in the molecule.
# 2022-02-02 16:18:11,248 - moleculekit.molecule - INFO - Removed 964 atoms. 63 atoms remaining in the molecule.
# 2022-02-02 16:18:11,297 - moleculekit.molecule - INFO - Removed 344 atoms. 56 atoms remaining in the molecule.
# 2022-02-02 16:18:11,350 - moleculekit.molecule - INFO - Removed 457 atoms. 64 atoms remaining in the molecule.
# 2022-02-02 16:18:11,415 - moleculekit.molecule - INFO - Removed 766 atoms. 118 atoms remaining in the molecule.
# 2022-02-02 16:18:11,484 - moleculekit.molecule - INFO - Removed 548 atoms. 85 atoms remaining in the molecule.
# 2022-02-02 16:18:11,562 - moleculekit.molecule - INFO - Removed 1048 atoms. 162 atoms remaining in the molecule.
# 2022-02-02 16:18:11,638 - moleculekit.molecule - INFO - Removed 1087 atoms. 71 atoms remaining in the molecule.
# 2022-02-02 16:18:11,724 - moleculekit.molecule - INFO - Removed 1202 atoms. 177 atoms remaining in the molecule.
# 2022-02-02 16:18:11,794 - moleculekit.molecule - INFO - Removed 793 atoms. 53 atoms remaining in the molecule.
# 2022-02-02 16:18:11,883 - moleculekit.molecule - INFO - Removed 1091 atoms. 161 atoms remaining in the molecule.
# 2022-02-02 16:18:11,943 - moleculekit.molecule - INFO - Removed 526 atoms. 73 atoms remaining in the molecule.
# 2022-02-02 16:18:12,010 - moleculekit.molecule - INFO - Removed 715 atoms. 95 atoms remaining in the molecule.
# 2022-02-02 16:18:12,067 - moleculekit.molecule - INFO - Removed 545 atoms. 84 atoms remaining in the molecule.
# 2022-02-02 16:18:12,167 - moleculekit.molecule - INFO - Removed 1382 atoms. 196 atoms remaining in the molecule.
# 2022-02-02 16:18:12,308 - moleculekit.molecule - INFO - Removed 2529 atoms. 388 atoms remaining in the molecule.
# 2022-02-02 16:18:12,368 - moleculekit.molecule - INFO - Removed 416 atoms. 58 atoms remaining in the molecule.
# 2022-02-02 16:18:12,444 - moleculekit.molecule - INFO - Removed 999 atoms. 145 atoms remaining in the molecule.
# 2022-02-02 16:18:12,523 - moleculekit.molecule - INFO - Removed 1033 atoms. 158 atoms remaining in the molecule.
# 2022-02-02 16:18:12,600 - moleculekit.molecule - INFO - Removed 962 atoms. 143 atoms remaining in the molecule.
# 2022-02-02 16:18:12,662 - moleculekit.molecule - INFO - Removed 654 atoms. 74 atoms remaining in the molecule.
# 2022-02-02 16:18:12,784 - moleculekit.molecule - INFO - Removed 1801 atoms. 269 atoms remaining in the molecule.
# 2022-02-02 16:18:12,906 - moleculekit.molecule - INFO - Removed 1850 atoms. 274 atoms remaining in the molecule.
# 2022-02-02 16:18:13,000 - moleculekit.molecule - INFO - Removed 1024 atoms. 153 atoms remaining in the molecule.
# 2022-02-02 16:18:13,090 - moleculekit.molecule - INFO - Removed 1326 atoms. 208 atoms remaining in the molecule.
# 2022-02-02 16:18:13,170 - moleculekit.molecule - INFO - Removed 1049 atoms. 141 atoms remaining in the molecule.
# 2022-02-02 16:18:13,247 - moleculekit.molecule - INFO - Removed 924 atoms. 141 atoms remaining in the molecule.
# 2022-02-02 16:18:13,334 - moleculekit.molecule - INFO - Removed 1186 atoms. 175 atoms remaining in the molecule.
# 2022-02-02 16:18:13,464 - moleculekit.molecule - INFO - Removed 2256 atoms. 332 atoms remaining in the molecule.
# 2022-02-02 16:18:13,580 - moleculekit.molecule - INFO - Removed 1853 atoms. 267 atoms remaining in the molecule.
# 2022-02-02 16:18:13,653 - moleculekit.molecule - INFO - Removed 624 atoms. 88 atoms remaining in the molecule.
# 2022-02-02 16:18:13,769 - moleculekit.molecule - INFO - Removed 1599 atoms. 223 atoms remaining in the molecule.
# 2022-02-02 16:18:13,852 - moleculekit.molecule - INFO - Removed 1014 atoms. 154 atoms remaining in the molecule.
# 2022-02-02 16:18:13,948 - moleculekit.molecule - INFO - Removed 1259 atoms. 180 atoms remaining in the molecule.
# 2022-02-02 16:18:14,070 - moleculekit.molecule - INFO - Removed 2047 atoms. 318 atoms remaining in the molecule.
# 2022-02-02 16:18:14,144 - moleculekit.molecule - INFO - Removed 913 atoms. 60 atoms remaining in the molecule.
# 2022-02-02 16:18:14,236 - moleculekit.molecule - INFO - Removed 1316 atoms. 187 atoms remaining in the molecule.
# 2022-02-02 16:18:14,323 - moleculekit.molecule - INFO - Removed 1220 atoms. 176 atoms remaining in the molecule.
# 2022-02-02 16:18:14,472 - moleculekit.molecule - INFO - Removed 2798 atoms. 404 atoms remaining in the molecule.
# 2022-02-02 16:18:14,543 - moleculekit.molecule - INFO - Removed 661 atoms. 97 atoms remaining in the molecule.
# 2022-02-02 16:18:14,599 - moleculekit.molecule - INFO - Removed 514 atoms. 76 atoms remaining in the molecule.
# 2022-02-02 16:18:14,708 - moleculekit.molecule - INFO - Removed 1623 atoms. 108 atoms remaining in the molecule.
# 2022-02-02 16:18:14,801 - moleculekit.molecule - INFO - Removed 1249 atoms. 188 atoms remaining in the molecule.
# 2022-02-02 16:18:14,872 - moleculekit.molecule - INFO - Removed 791 atoms. 115 atoms remaining in the molecule.
# 2022-02-02 16:18:14,985 - moleculekit.molecule - INFO - Removed 1862 atoms. 269 atoms remaining in the molecule.
# 2022-02-02 16:18:15,045 - moleculekit.molecule - INFO - Removed 435 atoms. 67 atoms remaining in the molecule.
# 2022-02-02 16:18:15,132 - moleculekit.molecule - INFO - Removed 1308 atoms. 191 atoms remaining in the molecule.
# 2022-02-02 16:18:15,249 - moleculekit.molecule - INFO - Removed 2061 atoms. 140 atoms remaining in the molecule.
# 2022-02-02 16:18:15,321 - moleculekit.molecule - INFO - Removed 838 atoms. 116 atoms remaining in the molecule.
# 2022-02-02 16:18:15,388 - moleculekit.molecule - INFO - Removed 842 atoms. 56 atoms remaining in the molecule.
# 2022-02-02 16:18:15,466 - moleculekit.molecule - INFO - Removed 870 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:18:15,523 - moleculekit.molecule - INFO - Removed 579 atoms. 51 atoms remaining in the molecule.
# 2022-02-02 16:18:15,594 - moleculekit.molecule - INFO - Removed 665 atoms. 89 atoms remaining in the molecule.
# 2022-02-02 16:18:15,663 - moleculekit.molecule - INFO - Removed 857 atoms. 120 atoms remaining in the molecule.
# 2022-02-02 16:18:15,729 - moleculekit.molecule - INFO - Removed 407 atoms. 61 atoms remaining in the molecule.
# 2022-02-02 16:18:15,793 - moleculekit.molecule - INFO - Removed 672 atoms. 106 atoms remaining in the molecule.
# 2022-02-02 16:18:15,849 - moleculekit.molecule - INFO - Removed 442 atoms. 68 atoms remaining in the molecule.
# 2022-02-02 16:18:15,927 - moleculekit.molecule - INFO - Removed 1034 atoms. 158 atoms remaining in the molecule.
# 2022-02-02 16:18:16,035 - moleculekit.molecule - INFO - Removed 1657 atoms. 261 atoms remaining in the molecule.
# 2022-02-02 16:18:16,113 - moleculekit.molecule - INFO - Removed 905 atoms. 139 atoms remaining in the molecule.
# 2022-02-02 16:18:16,174 - moleculekit.molecule - INFO - Removed 538 atoms. 79 atoms remaining in the molecule.
# 2022-02-02 16:18:16,234 - moleculekit.molecule - INFO - Removed 534 atoms. 99 atoms remaining in the molecule.
# 2022-02-02 16:18:16,367 - moleculekit.molecule - INFO - Removed 2008 atoms. 295 atoms remaining in the molecule.
# 2022-02-02 16:18:16,472 - moleculekit.molecule - INFO - Removed 1543 atoms. 228 atoms remaining in the molecule.
# 2022-02-02 16:18:16,532 - moleculekit.molecule - INFO - Removed 523 atoms. 75 atoms remaining in the molecule.
# 2022-02-02 16:18:16,607 - moleculekit.molecule - INFO - Removed 912 atoms. 132 atoms remaining in the molecule.
# 2022-02-02 16:18:16,670 - moleculekit.molecule - INFO - Removed 638 atoms. 86 atoms remaining in the molecule.
# 2022-02-02 16:18:16,733 - moleculekit.molecule - INFO - Removed 603 atoms. 88 atoms remaining in the molecule.
# 2022-02-02 16:18:16,785 - moleculekit.molecule - INFO - Removed 368 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:18:16,875 - moleculekit.molecule - INFO - Removed 1328 atoms. 185 atoms remaining in the molecule.
# 2022-02-02 16:18:16,968 - moleculekit.molecule - INFO - Removed 1105 atoms. 158 atoms remaining in the molecule.
# 2022-02-02 16:18:17,040 - moleculekit.molecule - INFO - Removed 773 atoms. 104 atoms remaining in the molecule.
# 2022-02-02 16:18:17,106 - moleculekit.molecule - INFO - Removed 823 atoms. 60 atoms remaining in the molecule.
# 2022-02-02 16:18:17,199 - moleculekit.molecule - INFO - Removed 1420 atoms. 210 atoms remaining in the molecule.
# 2022-02-02 16:18:17,272 - moleculekit.molecule - INFO - Removed 765 atoms. 113 atoms remaining in the molecule.
# 2022-02-02 16:18:17,332 - moleculekit.molecule - INFO - Removed 581 atoms. 75 atoms remaining in the molecule.
# 2022-02-02 16:18:17,400 - moleculekit.molecule - INFO - Removed 781 atoms. 105 atoms remaining in the molecule.
# 2022-02-02 16:18:17,520 - moleculekit.molecule - INFO - Removed 2271 atoms. 154 atoms remaining in the molecule.
# 2022-02-02 16:18:17,627 - moleculekit.molecule - INFO - Removed 1760 atoms. 264 atoms remaining in the molecule.
# 2022-02-02 16:18:17,697 - moleculekit.molecule - INFO - Removed 527 atoms. 76 atoms remaining in the molecule.
# 2022-02-02 16:18:17,763 - moleculekit.molecule - INFO - Removed 681 atoms. 99 atoms remaining in the molecule.
# 2022-02-02 16:18:17,842 - moleculekit.molecule - INFO - Removed 1045 atoms. 151 atoms remaining in the molecule.
# 2022-02-02 16:18:17,969 - moleculekit.molecule - INFO - Removed 2151 atoms. 316 atoms remaining in the molecule.
# 2022-02-02 16:18:18,029 - moleculekit.molecule - INFO - Removed 411 atoms. 61 atoms remaining in the molecule.
# 2022-02-02 16:18:18,147 - moleculekit.molecule - INFO - Removed 1768 atoms. 247 atoms remaining in the molecule.
# 2022-02-02 16:18:18,228 - moleculekit.molecule - INFO - Removed 950 atoms. 139 atoms remaining in the molecule.
# 2022-02-02 16:18:18,319 - moleculekit.molecule - INFO - Removed 1279 atoms. 189 atoms remaining in the molecule.
# 2022-02-02 16:18:18,432 - moleculekit.molecule - INFO - Removed 1694 atoms. 234 atoms remaining in the molecule.
# 2022-02-02 16:18:18,526 - moleculekit.molecule - INFO - Removed 1318 atoms. 198 atoms remaining in the molecule.
# 2022-02-02 16:18:18,582 - moleculekit.molecule - INFO - Removed 428 atoms. 61 atoms remaining in the molecule.
# 2022-02-02 16:18:18,634 - moleculekit.molecule - INFO - Removed 385 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:18:18,700 - moleculekit.molecule - INFO - Removed 744 atoms. 118 atoms remaining in the molecule.
# 2022-02-02 16:18:18,835 - moleculekit.molecule - INFO - Removed 2094 atoms. 339 atoms remaining in the molecule.
# 2022-02-02 16:18:18,901 - moleculekit.molecule - INFO - Removed 562 atoms. 80 atoms remaining in the molecule.
# 2022-02-02 16:18:18,993 - moleculekit.molecule - INFO - Removed 1343 atoms. 190 atoms remaining in the molecule.
# 2022-02-02 16:18:19,092 - moleculekit.molecule - INFO - Removed 1211 atoms. 83 atoms remaining in the molecule.
# 2022-02-02 16:18:19,170 - moleculekit.molecule - INFO - Removed 1015 atoms. 67 atoms remaining in the molecule.
# 2022-02-02 16:18:19,230 - moleculekit.molecule - INFO - Removed 534 atoms. 74 atoms remaining in the molecule.
# 2022-02-02 16:18:19,285 - moleculekit.molecule - INFO - Removed 442 atoms. 65 atoms remaining in the molecule.
# 2022-02-02 16:18:19,343 - moleculekit.molecule - INFO - Removed 548 atoms. 79 atoms remaining in the molecule.
# 2022-02-02 16:18:19,412 - moleculekit.molecule - INFO - Removed 754 atoms. 104 atoms remaining in the molecule.
# ...
# 2022-02-02 16:25:05,114 - moleculekit.molecule - INFO - Removed 650 atoms. 94 atoms remaining in the molecule.
# 2022-02-02 16:25:05,223 - moleculekit.molecule - INFO - Removed 1863 atoms. 124 atoms remaining in the molecule.
# 2022-02-02 16:25:05,280 - moleculekit.molecule - INFO - Removed 499 atoms. 69 atoms remaining in the molecule.
# 2022-02-02 16:25:05,353 - moleculekit.molecule - INFO - Removed 882 atoms. 124 atoms remaining in the molecule.
# 2022-02-02 16:25:05,457 - moleculekit.molecule - INFO - Removed 1669 atoms. 262 atoms remaining in the molecule.
# 2022-02-02 16:25:05,519 - moleculekit.molecule - INFO - Removed 562 atoms. 79 atoms remaining in the molecule.
# 2022-02-02 16:25:05,597 - moleculekit.molecule - INFO - Removed 1097 atoms. 78 atoms remaining in the molecule.
# 2022-02-02 16:25:05,661 - moleculekit.molecule - INFO - Removed 717 atoms. 105 atoms remaining in the molecule.
# 2022-02-02 16:25:05,755 - moleculekit.molecule - INFO - Removed 1553 atoms. 101 atoms remaining in the molecule.
# 2022-02-02 16:25:05,805 - moleculekit.molecule - INFO - Removed 360 atoms. 52 atoms remaining in the molecule.
# 2022-02-02 16:25:05,887 - moleculekit.molecule - INFO - Removed 949 atoms. 137 atoms remaining in the molecule.
# 2022-02-02 16:25:05,979 - moleculekit.molecule - INFO - Removed 1409 atoms. 212 atoms remaining in the molecule.
# 2022-02-02 16:25:06,059 - moleculekit.molecule - INFO - Removed 1029 atoms. 147 atoms remaining in the molecule.
# 2022-02-02 16:25:06,159 - moleculekit.molecule - INFO - Removed 1401 atoms. 199 atoms remaining in the molecule.
# 2022-02-02 16:25:06,236 - moleculekit.molecule - INFO - Removed 989 atoms. 136 atoms remaining in the molecule.
# 2022-02-02 16:25:06,341 - moleculekit.molecule - INFO - Removed 1675 atoms. 246 atoms remaining in the molecule.
# 2022-02-02 16:25:06,452 - moleculekit.molecule - INFO - Removed 1581 atoms. 229 atoms remaining in the molecule.
# 2022-02-02 16:25:06,541 - moleculekit.molecule - INFO - Removed 1280 atoms. 204 atoms remaining in the molecule.
# 2022-02-02 16:25:06,627 - moleculekit.molecule - INFO - Removed 1315 atoms. 87 atoms remaining in the molecule.
# 2022-02-02 16:25:06,726 - moleculekit.molecule - INFO - Removed 1591 atoms. 235 atoms remaining in the molecule.
# 2022-02-02 16:25:06,846 - moleculekit.molecule - INFO - Removed 2036 atoms. 298 atoms remaining in the molecule.
# 2022-02-02 16:25:06,956 - moleculekit.molecule - INFO - Removed 1668 atoms. 240 atoms remaining in the molecule.
# 2022-02-02 16:25:07,027 - moleculekit.molecule - INFO - Removed 802 atoms. 127 atoms remaining in the molecule.
# 2022-02-02 16:25:07,125 - moleculekit.molecule - INFO - Removed 1445 atoms. 212 atoms remaining in the molecule.
# 2022-02-02 16:25:07,196 - moleculekit.molecule - INFO - Removed 740 atoms. 103 atoms remaining in the molecule.
# 2022-02-02 16:25:07,292 - moleculekit.molecule - INFO - Removed 1415 atoms. 206 atoms remaining in the molecule.
# 2022-02-02 16:25:07,351 - moleculekit.molecule - INFO - Removed 428 atoms. 65 atoms remaining in the molecule.
# 2022-02-02 16:25:07,409 - moleculekit.molecule - INFO - Removed 539 atoms. 76 atoms remaining in the molecule.
# 2022-02-02 16:25:07,495 - moleculekit.molecule - INFO - Removed 1201 atoms. 175 atoms remaining in the molecule.
# 2022-02-02 16:25:07,566 - moleculekit.molecule - INFO - Removed 817 atoms. 117 atoms remaining in the molecule.
# 2022-02-02 16:25:07,647 - moleculekit.molecule - INFO - Removed 782 atoms. 116 atoms remaining in the molecule.
# 2022-02-02 16:25:07,715 - moleculekit.molecule - INFO - Removed 836 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:25:07,768 - moleculekit.molecule - INFO - Removed 437 atoms. 63 atoms remaining in the molecule.
# 2022-02-02 16:25:07,832 - moleculekit.molecule - INFO - Removed 697 atoms. 99 atoms remaining in the molecule.
# 2022-02-02 16:25:07,897 - moleculekit.molecule - INFO - Removed 667 atoms. 95 atoms remaining in the molecule.
# 2022-02-02 16:25:07,974 - moleculekit.molecule - INFO - Removed 1009 atoms. 155 atoms remaining in the molecule.
# 2022-02-02 16:25:08,025 - moleculekit.molecule - INFO - Removed 366 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:25:08,077 - moleculekit.molecule - INFO - Removed 396 atoms. 59 atoms remaining in the molecule.
# 2022-02-02 16:25:08,157 - moleculekit.molecule - INFO - Removed 968 atoms. 139 atoms remaining in the molecule.
# 2022-02-02 16:25:08,227 - moleculekit.molecule - INFO - Removed 773 atoms. 110 atoms remaining in the molecule.
# 2022-02-02 16:25:08,302 - moleculekit.molecule - INFO - Removed 898 atoms. 138 atoms remaining in the molecule.
# 2022-02-02 16:25:08,397 - moleculekit.molecule - INFO - Removed 1270 atoms. 185 atoms remaining in the molecule.
# 2022-02-02 16:25:08,489 - moleculekit.molecule - INFO - Removed 1415 atoms. 95 atoms remaining in the molecule.
# 2022-02-02 16:25:08,555 - moleculekit.molecule - INFO - Removed 750 atoms. 53 atoms remaining in the molecule.
# 2022-02-02 16:25:08,631 - moleculekit.molecule - INFO - Removed 1052 atoms. 70 atoms remaining in the molecule.
# 2022-02-02 16:25:08,725 - moleculekit.molecule - INFO - Removed 1489 atoms. 99 atoms remaining in the molecule.
# 2022-02-02 16:25:08,893 - moleculekit.molecule - INFO - Removed 3478 atoms. 226 atoms remaining in the molecule.
# 2022-02-02 16:25:09,029 - moleculekit.molecule - INFO - Removed 2516 atoms. 178 atoms remaining in the molecule.
# 2022-02-02 16:25:09,101 - moleculekit.molecule - INFO - Removed 838 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:25:09,223 - moleculekit.molecule - INFO - Removed 2156 atoms. 160 atoms remaining in the molecule.
# 2022-02-02 16:25:09,302 - moleculekit.molecule - INFO - Removed 1046 atoms. 65 atoms remaining in the molecule.
# 2022-02-02 16:25:09,438 - moleculekit.molecule - INFO - Removed 1385 atoms. 94 atoms remaining in the molecule.
# 2022-02-02 16:25:09,528 - moleculekit.molecule - INFO - Removed 1452 atoms. 107 atoms remaining in the molecule.
# 2022-02-02 16:25:09,609 - moleculekit.molecule - INFO - Removed 1105 atoms. 159 atoms remaining in the molecule.
# 2022-02-02 16:25:09,687 - moleculekit.molecule - INFO - Removed 908 atoms. 132 atoms remaining in the molecule.
# 2022-02-02 16:25:09,758 - moleculekit.molecule - INFO - Removed 785 atoms. 110 atoms remaining in the molecule.
# 2022-02-02 16:25:09,822 - moleculekit.molecule - INFO - Removed 650 atoms. 91 atoms remaining in the molecule.
# 2022-02-02 16:25:09,884 - moleculekit.molecule - INFO - Removed 582 atoms. 84 atoms remaining in the molecule.
# 2022-02-02 16:25:09,938 - moleculekit.molecule - INFO - Removed 437 atoms. 66 atoms remaining in the molecule.
# 2022-02-02 16:25:09,997 - moleculekit.molecule - INFO - Removed 595 atoms. 84 atoms remaining in the molecule.
# 2022-02-02 16:25:10,096 - moleculekit.molecule - INFO - Removed 1634 atoms. 119 atoms remaining in the molecule.
# 2022-02-02 16:25:10,196 - moleculekit.molecule - INFO - Removed 1145 atoms. 171 atoms remaining in the molecule.
# 2022-02-02 16:25:10,252 - moleculekit.molecule - INFO - Removed 367 atoms. 55 atoms remaining in the molecule.
# 2022-02-02 16:25:10,308 - moleculekit.molecule - INFO - Removed 438 atoms. 57 atoms remaining in the molecule.
# 2022-02-02 16:25:10,408 - moleculekit.molecule - INFO - Removed 1504 atoms. 103 atoms remaining in the molecule.
# 2022-02-02 16:25:10,553 - moleculekit.molecule - INFO - Removed 1763 atoms. 259 atoms remaining in the molecule.
# 2022-02-02 16:25:10,626 - moleculekit.molecule - INFO - Removed 704 atoms. 105 atoms remaining in the molecule.
# 2022-02-02 16:25:10,712 - moleculekit.molecule - INFO - Removed 1214 atoms. 172 atoms remaining in the molecule.
# 2022-02-02 16:25:10,785 - moleculekit.molecule - INFO - Removed 892 atoms. 125 atoms remaining in the molecule.
# 2022-02-02 16:25:10,899 - moleculekit.molecule - INFO - Removed 1822 atoms. 250 atoms remaining in the molecule.
# 2022-02-02 16:25:10,974 - moleculekit.molecule - INFO - Removed 912 atoms. 137 atoms remaining in the molecule.
# 2022-02-02 16:25:11,036 - moleculekit.molecule - INFO - Removed 618 atoms. 86 atoms remaining in the molecule.
# 2022-02-02 16:25:11,144 - moleculekit.molecule - INFO - Removed 1744 atoms. 256 atoms remaining in the molecule.
# 2022-02-02 16:25:11,208 - moleculekit.molecule - INFO - Removed 609 atoms. 82 atoms remaining in the molecule.
# 2022-02-02 16:25:11,293 - moleculekit.molecule - INFO - Removed 1262 atoms. 183 atoms remaining in the molecule.
# 2022-02-02 16:25:11,347 - moleculekit.molecule - INFO - Removed 373 atoms. 52 atoms remaining in the molecule.
# 2022-02-02 16:25:11,403 - moleculekit.molecule - INFO - Removed 549 atoms. 90 atoms remaining in the molecule.
# 2022-02-02 16:25:11,520 - moleculekit.molecule - INFO - Removed 2038 atoms. 319 atoms remaining in the molecule.
# 2022-02-02 16:25:11,603 - moleculekit.molecule - INFO - Removed 1051 atoms. 152 atoms remaining in the molecule.
# 2022-02-02 16:25:11,775 - moleculekit.molecule - INFO - Removed 3473 atoms. 500 atoms remaining in the molecule.
# 2022-02-02 16:25:11,841 - moleculekit.molecule - INFO - Removed 546 atoms. 72 atoms remaining in the molecule.
# 2022-02-02 16:25:11,929 - moleculekit.molecule - INFO - Removed 1311 atoms. 184 atoms remaining in the molecule.
# 2022-02-02 16:25:12,044 - moleculekit.molecule - INFO - Removed 1967 atoms. 281 atoms remaining in the molecule.
# 2022-02-02 16:25:12,161 - moleculekit.molecule - INFO - Removed 1763 atoms. 268 atoms remaining in the molecule.
# 2022-02-02 16:25:12,287 - moleculekit.molecule - INFO - Removed 2134 atoms. 307 atoms remaining in the molecule.
# 2022-02-02 16:25:12,378 - moleculekit.molecule - INFO - Removed 1049 atoms. 171 atoms remaining in the molecule.
# 2022-02-02 16:25:12,454 - moleculekit.molecule - INFO - Removed 886 atoms. 133 atoms remaining in the molecule.
# 2022-02-02 16:25:12,520 - moleculekit.molecule - INFO - Removed 594 atoms. 85 atoms remaining in the molecule.
# 2022-02-02 16:25:12,615 - moleculekit.molecule - INFO - Removed 1319 atoms. 196 atoms remaining in the molecule.
# 2022-02-02 16:25:12,734 - moleculekit.molecule - INFO - Removed 1875 atoms. 284 atoms remaining in the molecule.
# 2022-02-02 16:25:12,796 - moleculekit.molecule - INFO - Removed 454 atoms. 72 atoms remaining in the molecule.
# 2022-02-02 16:25:12,877 - moleculekit.molecule - INFO - Removed 1035 atoms. 69 atoms remaining in the molecule.
# 2022-02-02 16:25:12,955 - moleculekit.molecule - INFO - Removed 1144 atoms. 78 atoms remaining in the molecule.
# 2022-02-02 16:25:13,030 - moleculekit.molecule - INFO - Removed 943 atoms. 132 atoms remaining in the molecule.
# 2022-02-02 16:25:13,128 - moleculekit.molecule - INFO - Removed 1378 atoms. 214 atoms remaining in the molecule.
# 2022-02-02 16:25:13,236 - moleculekit.molecule - INFO - Removed 1668 atoms. 240 atoms remaining in the molecule.
# 2022-02-02 16:25:13,334 - moleculekit.molecule - INFO - Removed 907 atoms. 133 atoms remaining in the molecule.
# 2022-02-02 16:25:13,401 - moleculekit.molecule - INFO - Removed 645 atoms. 99 atoms remaining in the molecule.
# 2022-02-02 16:25:13,515 - moleculekit.molecule - INFO - Removed 2061 atoms. 136 atoms remaining in the molecule.
# 2022-02-02 16:25:13,612 - moleculekit.molecule - INFO - Removed 1388 atoms. 211 atoms remaining in the molecule.
# 2022-02-02 16:25:13,718 - moleculekit.molecule - INFO - Removed 1377 atoms. 208 atoms remaining in the molecule.
# 2022-02-02 16:25:13,844 - moleculekit.molecule - INFO - Removed 1958 atoms. 132 atoms remaining in the molecule.
# 2022-02-02 16:25:13,942 - moleculekit.molecule - INFO - Removed 1597 atoms. 99 atoms remaining in the molecule.
# 2022-02-02 16:25:14,043 - moleculekit.molecule - INFO - Removed 1670 atoms. 106 atoms remaining in the molecule.
# 2022-02-02 16:25:14,146 - moleculekit.molecule - INFO - Removed 1632 atoms. 107 atoms remaining in the molecule.
# 2022-02-02 16:25:14,221 - moleculekit.molecule - INFO - Removed 928 atoms. 133 atoms remaining in the molecule.
# 2022-02-02 16:25:14,300 - moleculekit.molecule - INFO - Removed 901 atoms. 126 atoms remaining in the molecule.
# 2022-02-02 16:25:14,363 - moleculekit.molecule - INFO - Removed 521 atoms. 80 atoms remaining in the molecule.
# 2022-02-02 16:25:14,438 - moleculekit.molecule - INFO - Removed 845 atoms. 125 atoms remaining in the molecule.
# 2022-02-02 16:25:14,514 - moleculekit.molecule - INFO - Removed 948 atoms. 134 atoms remaining in the molecule.
# 2022-02-02 16:25:14,598 - moleculekit.molecule - INFO - Removed 1103 atoms. 157 atoms remaining in the molecule.
# 2022-02-02 16:25:14,660 - moleculekit.molecule - INFO - Removed 553 atoms. 81 atoms remaining in the molecule.
# 2022-02-02 16:25:14,713 - moleculekit.molecule - INFO - Removed 356 atoms. 53 atoms remaining in the molecule.
# 2022-02-02 16:25:14,771 - moleculekit.molecule - INFO - Removed 521 atoms. 77 atoms remaining in the molecule.
# 2022-02-02 16:25:14,870 - moleculekit.molecule - INFO - Removed 1506 atoms. 227 atoms remaining in the molecule.
# 2022-02-02 16:25:14,949 - moleculekit.molecule - INFO - Removed 905 atoms. 140 atoms remaining in the molecule.
# 2022-02-02 16:25:15,013 - moleculekit.molecule - INFO - Removed 630 atoms. 90 atoms remaining in the molecule.
# 2022-02-02 16:25:15,093 - moleculekit.molecule - INFO - Removed 986 atoms. 142 atoms remaining in the molecule.
# 2022-02-02 16:25:15,152 - moleculekit.molecule - INFO - Removed 452 atoms. 63 atoms remaining in the molecule.
# 2022-02-02 16:25:15,226 - moleculekit.molecule - INFO - Removed 913 atoms. 132 atoms remaining in the molecule.
# 2022-02-02 16:25:15,286 - moleculekit.molecule - INFO - Removed 539 atoms. 79 atoms remaining in the molecule.
# 2022-02-02 16:25:15,378 - moleculekit.molecule - INFO - Removed 1235 atoms. 168 atoms remaining in the molecule.
# 2022-02-02 16:25:15,518 - moleculekit.molecule - INFO - Removed 2486 atoms. 357 atoms remaining in the molecule.
# 2022-02-02 16:25:15,600 - moleculekit.molecule - INFO - Removed 985 atoms. 69 atoms remaining in the molecule.
# 2022-02-02 16:25:15,662 - moleculekit.molecule - INFO - Removed 406 atoms. 55 atoms remaining in the molecule.
# 2022-02-02 16:25:15,768 - moleculekit.molecule - INFO - Removed 1710 atoms. 239 atoms remaining in the molecule.
# 2022-02-02 16:25:15,830 - moleculekit.molecule - INFO - Removed 493 atoms. 66 atoms remaining in the molecule.
# 2022-02-02 16:25:15,931 - moleculekit.molecule - INFO - Removed 1534 atoms. 220 atoms remaining in the molecule.
# 2022-02-02 16:25:16,009 - moleculekit.molecule - INFO - Removed 885 atoms. 129 atoms remaining in the molecule.
# 2022-02-02 16:25:16,095 - moleculekit.molecule - INFO - Removed 1129 atoms. 164 atoms remaining in the molecule.
# 2022-02-02 16:25:16,149 - moleculekit.molecule - INFO - Removed 356 atoms. 50 atoms remaining in the molecule.
# 2022-02-02 16:25:16,236 - moleculekit.molecule - INFO - Removed 1197 atoms. 170 atoms remaining in the molecule.
# 2022-02-02 16:25:16,318 - moleculekit.molecule - INFO - Removed 1077 atoms. 165 atoms remaining in the molecule.
# 2022-02-02 16:25:16,413 - moleculekit.molecule - INFO - Removed 1394 atoms. 213 atoms remaining in the molecule.
# 2022-02-02 16:25:16,498 - moleculekit.molecule - INFO - Removed 1120 atoms. 166 atoms remaining in the molecule.
# 2022-02-02 16:25:16,553 - moleculekit.molecule - INFO - Removed 402 atoms. 58 atoms remaining in the molecule.
# 2022-02-02 16:25:16,666 - moleculekit.molecule - INFO - Removed 1830 atoms. 278 atoms remaining in the molecule.
# 2022-02-02 16:25:16,767 - moleculekit.molecule - INFO - Removed 1529 atoms. 112 atoms remaining in the molecule.
# 2022-02-02 16:25:16,841 - moleculekit.molecule - INFO - Removed 851 atoms. 122 atoms remaining in the molecule.
# 2022-02-02 16:25:16,920 - moleculekit.molecule - INFO - Removed 955 atoms. 139 atoms remaining in the molecule.
# 2022-02-02 16:25:16,982 - moleculekit.molecule - INFO - Removed 619 atoms. 87 atoms remaining in the molecule.
# 2022-02-02 16:25:17,035 - moleculekit.molecule - INFO - Removed 371 atoms. 53 atoms remaining in the molecule.

# %%
mol = Molecule(f'/workspace7/torchmd-AD/carles_cath/9b_good_train/1jfk/level_0/ground_truth/1jfk.pdb')

# %%
mol_topo = pdb2psf_CA(mol, angles=False)

# %%
psf = f'/workspace7/torchmd-AD/carles_cath/9b_good_topology/1jfk.psf'

# %%
mol_topo.write(f'/workspace7/torchmd-AD/carles_cath/9b_good_topology/1jfk.psf')

# %% [markdown]
# ## Extract CA

# %%
names = open('/shared/carles/torchmd-exp/datasets/cgdms_dataset.txt')
names = [name.strip() for name in names]

# %%
i = 0
for name in names:
    i += 1
    pdb = f'/workspace7/torchmd-AD/cgdms/cgdms_domains/level_0/ground_truth/{name}.pdb'
    mol = Molecule(pdb)
    mol.filter('name CA')
    mol.write(f'/workspace7/torchmd-AD/cgdms/cgdms_levels/level_0/ground_truth/{name}.pdb')
# Out:
# 2022-03-16 16:36:33,514 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:33,517 - moleculekit.molecule - INFO - Removed 4 atoms. 50 atoms remaining in the molecule.
# 2022-03-16 16:36:33,608 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:33,610 - moleculekit.molecule - INFO - Removed 8 atoms. 73 atoms remaining in the molecule.
# 2022-03-16 16:36:33,698 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:33,700 - moleculekit.molecule - INFO - Removed 22 atoms. 87 atoms remaining in the molecule.
# 2022-03-16 16:36:34,224 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,226 - moleculekit.molecule - INFO - Removed 12 atoms. 56 atoms remaining in the molecule.
# 2022-03-16 16:36:34,308 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,310 - moleculekit.molecule - INFO - Removed 1 atoms. 20 atoms remaining in the molecule.
# 2022-03-16 16:36:34,351 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,353 - moleculekit.molecule - INFO - Removed 1 atoms. 83 atoms remaining in the molecule.
# 2022-03-16 16:36:34,398 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,399 - moleculekit.molecule - INFO - Removed 2 atoms. 82 atoms remaining in the molecule.
# 2022-03-16 16:36:34,485 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,486 - moleculekit.molecule - INFO - Removed 6 atoms. 94 atoms remaining in the molecule.
# 2022-03-16 16:36:34,528 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,530 - moleculekit.molecule - INFO - Removed 1 atoms. 36 atoms remaining in the molecule.
# 2022-03-16 16:36:34,648 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,649 - moleculekit.molecule - INFO - Removed 1 atoms. 21 atoms remaining in the molecule.
# 2022-03-16 16:36:34,688 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,690 - moleculekit.molecule - INFO - Removed 2 atoms. 82 atoms remaining in the molecule.
# 2022-03-16 16:36:34,732 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,734 - moleculekit.molecule - INFO - Removed 3 atoms. 64 atoms remaining in the molecule.
# 2022-03-16 16:36:34,859 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:34,860 - moleculekit.molecule - INFO - Removed 2 atoms. 24 atoms remaining in the molecule.
# 2022-03-16 16:36:35,154 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:35,155 - moleculekit.molecule - INFO - Removed 3 atoms. 77 atoms remaining in the molecule.
# 2022-03-16 16:36:35,235 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:35,237 - moleculekit.molecule - INFO - Removed 1 atoms. 30 atoms remaining in the molecule.
# 2022-03-16 16:36:35,278 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:35,280 - moleculekit.molecule - INFO - Removed 2 atoms. 52 atoms remaining in the molecule.
# 2022-03-16 16:36:35,325 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:35,327 - moleculekit.molecule - INFO - Removed 7 atoms. 94 atoms remaining in the molecule.
# 2022-03-16 16:36:35,677 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:35,679 - moleculekit.molecule - INFO - Removed 8 atoms. 48 atoms remaining in the molecule.
# 2022-03-16 16:36:35,855 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:35,857 - moleculekit.molecule - INFO - Removed 3 atoms. 83 atoms remaining in the molecule.
# 2022-03-16 16:36:36,026 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:36,030 - moleculekit.molecule - INFO - Removed 2 atoms. 83 atoms remaining in the molecule.
# 2022-03-16 16:36:36,121 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:36,123 - moleculekit.molecule - INFO - Removed 2 atoms. 90 atoms remaining in the molecule.
# 2022-03-16 16:36:36,251 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:36,252 - moleculekit.molecule - INFO - Removed 1 atoms. 82 atoms remaining in the molecule.
# 2022-03-16 16:36:36,633 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:36,634 - moleculekit.molecule - INFO - Removed 1 atoms. 41 atoms remaining in the molecule.
# 2022-03-16 16:36:36,802 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:36,804 - moleculekit.molecule - INFO - Removed 8 atoms. 72 atoms remaining in the molecule.
# 2022-03-16 16:36:36,933 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:36,935 - moleculekit.molecule - INFO - Removed 12 atoms. 100 atoms remaining in the molecule.
# 2022-03-16 16:36:37,055 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:37,057 - moleculekit.molecule - INFO - Removed 1 atoms. 21 atoms remaining in the molecule.
# 2022-03-16 16:36:37,137 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:37,138 - moleculekit.molecule - INFO - Removed 3 atoms. 68 atoms remaining in the molecule.
# 2022-03-16 16:36:37,430 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:37,431 - moleculekit.molecule - INFO - Removed 7 atoms. 29 atoms remaining in the molecule.
# 2022-03-16 16:36:37,541 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:37,543 - moleculekit.molecule - INFO - Removed 5 atoms. 81 atoms remaining in the molecule.
# 2022-03-16 16:36:37,585 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:37,587 - moleculekit.molecule - INFO - Removed 1 atoms. 25 atoms remaining in the molecule.
# 2022-03-16 16:36:37,667 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:37,669 - moleculekit.molecule - INFO - Removed 2 atoms. 62 atoms remaining in the molecule.
# 2022-03-16 16:36:37,793 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:37,795 - moleculekit.molecule - INFO - Removed 3 atoms. 86 atoms remaining in the molecule.
# 2022-03-16 16:36:37,841 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:37,843 - moleculekit.molecule - INFO - Removed 2 atoms. 66 atoms remaining in the molecule.
# 2022-03-16 16:36:38,010 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,012 - moleculekit.molecule - INFO - Removed 1 atoms. 92 atoms remaining in the molecule.
# 2022-03-16 16:36:38,057 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,059 - moleculekit.molecule - INFO - Removed 1 atoms. 91 atoms remaining in the molecule.
# 2022-03-16 16:36:38,102 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,103 - moleculekit.molecule - INFO - Removed 2 atoms. 44 atoms remaining in the molecule.
# 2022-03-16 16:36:38,187 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,189 - moleculekit.molecule - INFO - Removed 1 atoms. 50 atoms remaining in the molecule.
# 2022-03-16 16:36:38,314 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,316 - moleculekit.molecule - INFO - Removed 5 atoms. 32 atoms remaining in the molecule.
# 2022-03-16 16:36:38,537 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,539 - moleculekit.molecule - INFO - Removed 1 atoms. 28 atoms remaining in the molecule.
# 2022-03-16 16:36:38,794 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,796 - moleculekit.molecule - INFO - Removed 4 atoms. 91 atoms remaining in the molecule.
# 2022-03-16 16:36:38,841 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,842 - moleculekit.molecule - INFO - Removed 4 atoms. 93 atoms remaining in the molecule.
# 2022-03-16 16:36:38,929 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,931 - moleculekit.molecule - INFO - Removed 5 atoms. 82 atoms remaining in the molecule.
# 2022-03-16 16:36:38,973 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:38,975 - moleculekit.molecule - INFO - Removed 4 atoms. 35 atoms remaining in the molecule.
# 2022-03-16 16:36:39,103 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,105 - moleculekit.molecule - INFO - Removed 1 atoms. 46 atoms remaining in the molecule.
# 2022-03-16 16:36:39,155 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,158 - moleculekit.molecule - INFO - Removed 4 atoms. 81 atoms remaining in the molecule.
# 2022-03-16 16:36:39,288 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,289 - moleculekit.molecule - INFO - Removed 1 atoms. 22 atoms remaining in the molecule.
# 2022-03-16 16:36:39,331 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,332 - moleculekit.molecule - INFO - Removed 4 atoms. 83 atoms remaining in the molecule.
# 2022-03-16 16:36:39,377 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,379 - moleculekit.molecule - INFO - Removed 1 atoms. 46 atoms remaining in the molecule.
# 2022-03-16 16:36:39,639 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,640 - moleculekit.molecule - INFO - Removed 2 atoms. 65 atoms remaining in the molecule.
# 2022-03-16 16:36:39,684 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,685 - moleculekit.molecule - INFO - Removed 1 atoms. 29 atoms remaining in the molecule.
# 2022-03-16 16:36:39,769 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,770 - moleculekit.molecule - INFO - Removed 2 atoms. 33 atoms remaining in the molecule.
# 2022-03-16 16:36:39,856 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,858 - moleculekit.molecule - INFO - Removed 1 atoms. 40 atoms remaining in the molecule.
# 2022-03-16 16:36:39,903 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,904 - moleculekit.molecule - INFO - Removed 2 atoms. 39 atoms remaining in the molecule.
# 2022-03-16 16:36:39,945 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,947 - moleculekit.molecule - INFO - Removed 1 atoms. 29 atoms remaining in the molecule.
# 2022-03-16 16:36:39,990 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:39,992 - moleculekit.molecule - INFO - Removed 3 atoms. 81 atoms remaining in the molecule.
# 2022-03-16 16:36:40,080 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:40,081 - moleculekit.molecule - INFO - Removed 1 atoms. 37 atoms remaining in the molecule.
# 2022-03-16 16:36:40,212 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:40,214 - moleculekit.molecule - INFO - Removed 2 atoms. 30 atoms remaining in the molecule.
# 2022-03-16 16:36:40,300 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:40,301 - moleculekit.molecule - INFO - Removed 3 atoms. 66 atoms remaining in the molecule.
# 2022-03-16 16:36:40,475 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:40,477 - moleculekit.molecule - INFO - Removed 1 atoms. 65 atoms remaining in the molecule.
# 2022-03-16 16:36:40,867 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:40,869 - moleculekit.molecule - INFO - Removed 10 atoms. 68 atoms remaining in the molecule.
# 2022-03-16 16:36:40,953 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:40,955 - moleculekit.molecule - INFO - Removed 1 atoms. 70 atoms remaining in the molecule.
# 2022-03-16 16:36:41,087 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:41,088 - moleculekit.molecule - INFO - Removed 6 atoms. 87 atoms remaining in the molecule.
# 2022-03-16 16:36:41,594 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:41,596 - moleculekit.molecule - INFO - Removed 4 atoms. 67 atoms remaining in the molecule.
# 2022-03-16 16:36:41,808 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:41,810 - moleculekit.molecule - INFO - Removed 11 atoms. 86 atoms remaining in the molecule.
# 2022-03-16 16:36:41,811 - moleculekit.molecule - INFO - Removed 1 atoms. 85 atoms remaining in the molecule.
# 2022-03-16 16:36:41,941 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:41,943 - moleculekit.molecule - INFO - Removed 1 atoms. 92 atoms remaining in the molecule.
# 2022-03-16 16:36:42,529 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:42,531 - moleculekit.molecule - INFO - Removed 2 atoms. 56 atoms remaining in the molecule.
# 2022-03-16 16:36:42,699 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:42,700 - moleculekit.molecule - INFO - Removed 1 atoms. 81 atoms remaining in the molecule.
# 2022-03-16 16:36:42,909 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:42,910 - moleculekit.molecule - INFO - Removed 3 atoms. 91 atoms remaining in the molecule.
# 2022-03-16 16:36:43,037 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:43,039 - moleculekit.molecule - INFO - Removed 1 atoms. 37 atoms remaining in the molecule.
# 2022-03-16 16:36:43,123 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:43,124 - moleculekit.molecule - INFO - Removed 3 atoms. 77 atoms remaining in the molecule.
# 2022-03-16 16:36:43,168 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:43,169 - moleculekit.molecule - INFO - Removed 1 atoms. 50 atoms remaining in the molecule.
# 2022-03-16 16:36:43,212 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:43,214 - moleculekit.molecule - INFO - Removed 5 atoms. 72 atoms remaining in the molecule.
# 2022-03-16 16:36:43,257 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:43,258 - moleculekit.molecule - INFO - Removed 4 atoms. 65 atoms remaining in the molecule.
# 2022-03-16 16:36:43,342 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:43,344 - moleculekit.molecule - INFO - Removed 2 atoms. 71 atoms remaining in the molecule.
# 2022-03-16 16:36:43,388 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:43,390 - moleculekit.molecule - INFO - Removed 1 atoms. 87 atoms remaining in the molecule.
# 2022-03-16 16:36:43,477 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:43,478 - moleculekit.molecule - INFO - Removed 5 atoms. 85 atoms remaining in the molecule.
# 2022-03-16 16:36:43,982 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:43,983 - moleculekit.molecule - INFO - Removed 2 atoms. 59 atoms remaining in the molecule.
# 2022-03-16 16:36:43,985 - moleculekit.molecule - INFO - Removed 1 atoms. 58 atoms remaining in the molecule.
# 2022-03-16 16:36:44,079 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:44,082 - moleculekit.molecule - INFO - Removed 7 atoms. 67 atoms remaining in the molecule.
# 2022-03-16 16:36:44,258 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:44,260 - moleculekit.molecule - INFO - Removed 1 atoms. 74 atoms remaining in the molecule.
# 2022-03-16 16:36:44,390 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:44,392 - moleculekit.molecule - INFO - Removed 1 atoms. 71 atoms remaining in the molecule.
# 2022-03-16 16:36:44,436 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:44,438 - moleculekit.molecule - INFO - Removed 7 atoms. 67 atoms remaining in the molecule.
# 2022-03-16 16:36:44,747 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:44,748 - moleculekit.molecule - INFO - Removed 10 atoms. 93 atoms remaining in the molecule.
# 2022-03-16 16:36:44,749 - moleculekit.molecule - INFO - Removed 1 atoms. 92 atoms remaining in the molecule.
# 2022-03-16 16:36:44,793 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:44,795 - moleculekit.molecule - INFO - Removed 3 atoms. 89 atoms remaining in the molecule.
# 2022-03-16 16:36:44,840 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:44,842 - moleculekit.molecule - INFO - Removed 1 atoms. 76 atoms remaining in the molecule.
# 2022-03-16 16:36:44,924 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:44,926 - moleculekit.molecule - INFO - Removed 1 atoms. 50 atoms remaining in the molecule.
# 2022-03-16 16:36:44,972 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:44,973 - moleculekit.molecule - INFO - Removed 69 atoms. 85 atoms remaining in the molecule.
# 2022-03-16 16:36:44,975 - moleculekit.molecule - INFO - Removed 10 atoms. 75 atoms remaining in the molecule.
# 2022-03-16 16:36:45,102 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:45,103 - moleculekit.molecule - INFO - Removed 6 atoms. 92 atoms remaining in the molecule.
# 2022-03-16 16:36:45,230 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:45,232 - moleculekit.molecule - INFO - Removed 7 atoms. 55 atoms remaining in the molecule.
# 2022-03-16 16:36:45,757 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:45,758 - moleculekit.molecule - INFO - Removed 3 atoms. 34 atoms remaining in the molecule.
# 2022-03-16 16:36:45,759 - moleculekit.molecule - INFO - Removed 1 atoms. 33 atoms remaining in the molecule.
# 2022-03-16 16:36:45,975 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:45,976 - moleculekit.molecule - INFO - Removed 2 atoms. 49 atoms remaining in the molecule.
# 2022-03-16 16:36:46,432 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:46,433 - moleculekit.molecule - INFO - Removed 3 atoms. 57 atoms remaining in the molecule.
# 2022-03-16 16:36:46,573 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:46,575 - moleculekit.molecule - INFO - Removed 1 atoms. 68 atoms remaining in the molecule.
# 2022-03-16 16:36:46,676 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:46,678 - moleculekit.molecule - INFO - Removed 8 atoms. 81 atoms remaining in the molecule.
# 2022-03-16 16:36:46,679 - moleculekit.molecule - INFO - Removed 1 atoms. 80 atoms remaining in the molecule.
# 2022-03-16 16:36:46,859 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:46,861 - moleculekit.molecule - INFO - Removed 1 atoms. 66 atoms remaining in the molecule.
# 2022-03-16 16:36:46,942 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:46,943 - moleculekit.molecule - INFO - Removed 3 atoms. 53 atoms remaining in the molecule.
# 2022-03-16 16:36:47,061 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:47,063 - moleculekit.molecule - INFO - Removed 3 atoms. 88 atoms remaining in the molecule.
# 2022-03-16 16:36:47,111 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:47,113 - moleculekit.molecule - INFO - Removed 21 atoms. 97 atoms remaining in the molecule.
# 2022-03-16 16:36:47,170 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:47,171 - moleculekit.molecule - INFO - Removed 1 atoms. 62 atoms remaining in the molecule.
# 2022-03-16 16:36:47,326 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:47,328 - moleculekit.molecule - INFO - Removed 4 atoms. 88 atoms remaining in the molecule.
# 2022-03-16 16:36:47,461 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:47,462 - moleculekit.molecule - INFO - Removed 6 atoms. 56 atoms remaining in the molecule.
# 2022-03-16 16:36:47,557 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:47,559 - moleculekit.molecule - INFO - Removed 4 atoms. 66 atoms remaining in the molecule.
# 2022-03-16 16:36:47,656 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:47,658 - moleculekit.molecule - INFO - Removed 5 atoms. 51 atoms remaining in the molecule.
# 2022-03-16 16:36:47,835 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:47,837 - moleculekit.molecule - INFO - Removed 3 atoms. 70 atoms remaining in the molecule.
# 2022-03-16 16:36:47,880 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:47,882 - moleculekit.molecule - INFO - Removed 3 atoms. 75 atoms remaining in the molecule.
# 2022-03-16 16:36:47,882 - moleculekit.molecule - INFO - Removed 2 atoms. 73 atoms remaining in the molecule.
# 2022-03-16 16:36:48,102 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:48,104 - moleculekit.molecule - INFO - Removed 1 atoms. 39 atoms remaining in the molecule.
# 2022-03-16 16:36:48,204 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:48,206 - moleculekit.molecule - INFO - Removed 1 atoms. 87 atoms remaining in the molecule.
# 2022-03-16 16:36:48,297 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:48,298 - moleculekit.molecule - INFO - Removed 4 atoms. 90 atoms remaining in the molecule.
# 2022-03-16 16:36:48,343 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:48,345 - moleculekit.molecule - INFO - Removed 6 atoms. 85 atoms remaining in the molecule.
# 2022-03-16 16:36:48,636 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:48,637 - moleculekit.molecule - INFO - Removed 1 atoms. 70 atoms remaining in the molecule.
# 2022-03-16 16:36:48,723 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:48,725 - moleculekit.molecule - INFO - Removed 2 atoms. 33 atoms remaining in the molecule.
# 2022-03-16 16:36:49,065 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:49,066 - moleculekit.molecule - INFO - Removed 1 atoms. 66 atoms remaining in the molecule.
# 2022-03-16 16:36:49,261 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:49,263 - moleculekit.molecule - INFO - Removed 1 atoms. 24 atoms remaining in the molecule.
# 2022-03-16 16:36:49,401 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:49,403 - moleculekit.molecule - INFO - Removed 10 atoms. 60 atoms remaining in the molecule.
# 2022-03-16 16:36:49,404 - moleculekit.molecule - INFO - Removed 2 atoms. 58 atoms remaining in the molecule.
# 2022-03-16 16:36:49,447 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:49,450 - moleculekit.molecule - INFO - Removed 10 atoms. 65 atoms remaining in the molecule.
# 2022-03-16 16:36:49,452 - moleculekit.molecule - INFO - Removed 1 atoms. 64 atoms remaining in the molecule.
# 2022-03-16 16:36:49,501 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:49,503 - moleculekit.molecule - INFO - Removed 5 atoms. 64 atoms remaining in the molecule.
# 2022-03-16 16:36:49,616 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:49,617 - moleculekit.molecule - INFO - Removed 5 atoms. 37 atoms remaining in the molecule.
# 2022-03-16 16:36:49,757 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:49,758 - moleculekit.molecule - INFO - Removed 14 atoms. 98 atoms remaining in the molecule.
# 2022-03-16 16:36:49,802 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:49,804 - moleculekit.molecule - INFO - Removed 4 atoms. 55 atoms remaining in the molecule.
# 2022-03-16 16:36:50,143 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:50,145 - moleculekit.molecule - INFO - Removed 6 atoms. 80 atoms remaining in the molecule.
# 2022-03-16 16:36:50,302 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:50,304 - moleculekit.molecule - INFO - Removed 1 atoms. 27 atoms remaining in the molecule.
# 2022-03-16 16:36:50,425 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:50,427 - moleculekit.molecule - INFO - Removed 1 atoms. 94 atoms remaining in the molecule.
# 2022-03-16 16:36:50,561 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:50,563 - moleculekit.molecule - INFO - Removed 9 atoms. 76 atoms remaining in the molecule.
# 2022-03-16 16:36:50,564 - moleculekit.molecule - INFO - Removed 1 atoms. 75 atoms remaining in the molecule.
# 2022-03-16 16:36:50,866 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:50,867 - moleculekit.molecule - INFO - Removed 1 atoms. 93 atoms remaining in the molecule.
# 2022-03-16 16:36:50,911 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:50,912 - moleculekit.molecule - INFO - Removed 1 atoms. 57 atoms remaining in the molecule.
# 2022-03-16 16:36:50,955 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:50,957 - moleculekit.molecule - INFO - Removed 13 atoms. 82 atoms remaining in the molecule.
# 2022-03-16 16:36:51,000 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:51,001 - moleculekit.molecule - INFO - Removed 4 atoms. 64 atoms remaining in the molecule.
# 2022-03-16 16:36:51,302 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:51,304 - moleculekit.molecule - INFO - Removed 1 atoms. 72 atoms remaining in the molecule.
# 2022-03-16 16:36:51,347 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:51,348 - moleculekit.molecule - INFO - Removed 15 atoms. 86 atoms remaining in the molecule.
# 2022-03-16 16:36:51,350 - moleculekit.molecule - INFO - Removed 1 atoms. 85 atoms remaining in the molecule.
# 2022-03-16 16:36:51,609 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:51,610 - moleculekit.molecule - INFO - Removed 3 atoms. 46 atoms remaining in the molecule.
# 2022-03-16 16:36:51,653 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:51,654 - moleculekit.molecule - INFO - Removed 1 atoms. 90 atoms remaining in the molecule.
# 2022-03-16 16:36:51,824 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:51,825 - moleculekit.molecule - INFO - Removed 8 atoms. 80 atoms remaining in the molecule.
# 2022-03-16 16:36:52,128 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:52,130 - moleculekit.molecule - INFO - Removed 2 atoms. 23 atoms remaining in the molecule.
# 2022-03-16 16:36:52,480 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:52,483 - moleculekit.molecule - INFO - Removed 1 atoms. 39 atoms remaining in the molecule.
# 2022-03-16 16:36:52,583 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:52,585 - moleculekit.molecule - INFO - Removed 3 atoms. 66 atoms remaining in the molecule.
# 2022-03-16 16:36:52,586 - moleculekit.molecule - INFO - Removed 1 atoms. 65 atoms remaining in the molecule.
# 2022-03-16 16:36:52,643 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:52,645 - moleculekit.molecule - INFO - Removed 2 atoms. 25 atoms remaining in the molecule.
# 2022-03-16 16:36:52,646 - moleculekit.molecule - INFO - Removed 1 atoms. 24 atoms remaining in the molecule.
# 2022-03-16 16:36:52,689 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:52,690 - moleculekit.molecule - INFO - Removed 1 atoms. 54 atoms remaining in the molecule.
# 2022-03-16 16:36:52,907 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:52,909 - moleculekit.molecule - INFO - Removed 8 atoms. 91 atoms remaining in the molecule.
# 2022-03-16 16:36:52,963 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:52,965 - moleculekit.molecule - INFO - Removed 4 atoms. 82 atoms remaining in the molecule.
# 2022-03-16 16:36:53,396 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:53,398 - moleculekit.molecule - INFO - Removed 7 atoms. 68 atoms remaining in the molecule.
# 2022-03-16 16:36:53,480 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:53,482 - moleculekit.molecule - INFO - Removed 4 atoms. 50 atoms remaining in the molecule.
# 2022-03-16 16:36:53,484 - moleculekit.molecule - INFO - Removed 1 atoms. 49 atoms remaining in the molecule.
# 2022-03-16 16:36:53,538 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:53,540 - moleculekit.molecule - INFO - Removed 2 atoms. 83 atoms remaining in the molecule.
# 2022-03-16 16:36:53,817 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:53,819 - moleculekit.molecule - INFO - Removed 1 atoms. 22 atoms remaining in the molecule.
# 2022-03-16 16:36:53,859 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:53,860 - moleculekit.molecule - INFO - Removed 3 atoms. 28 atoms remaining in the molecule.
# 2022-03-16 16:36:53,902 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:53,904 - moleculekit.molecule - INFO - Removed 29 atoms. 84 atoms remaining in the molecule.
# 2022-03-16 16:36:53,905 - moleculekit.molecule - INFO - Removed 1 atoms. 83 atoms remaining in the molecule.
# 2022-03-16 16:36:54,190 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:54,192 - moleculekit.molecule - INFO - Removed 1 atoms. 88 atoms remaining in the molecule.
# 2022-03-16 16:36:54,271 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:54,273 - moleculekit.molecule - INFO - Removed 5 atoms. 25 atoms remaining in the molecule.
# 2022-03-16 16:36:54,274 - moleculekit.molecule - INFO - Removed 1 atoms. 24 atoms remaining in the molecule.
# 2022-03-16 16:36:54,843 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:54,844 - moleculekit.molecule - INFO - Removed 1 atoms. 77 atoms remaining in the molecule.
# 2022-03-16 16:36:55,354 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:55,355 - moleculekit.molecule - INFO - Removed 17 atoms. 98 atoms remaining in the molecule.
# 2022-03-16 16:36:55,400 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:36:55,401 - moleculekit.molecule - INFO - Removed 5 atoms. 89 atoms remaining in the molecule.
# ...
# 2022-03-16 16:37:58,695 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:58,697 - moleculekit.molecule - INFO - Removed 3 atoms. 87 atoms remaining in the molecule.
# 2022-03-16 16:37:58,738 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:58,740 - moleculekit.molecule - INFO - Removed 2 atoms. 67 atoms remaining in the molecule.
# 2022-03-16 16:37:58,786 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:58,788 - moleculekit.molecule - INFO - Removed 1 atoms. 53 atoms remaining in the molecule.
# 2022-03-16 16:37:58,846 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:58,848 - moleculekit.molecule - INFO - Removed 5 atoms. 91 atoms remaining in the molecule.
# 2022-03-16 16:37:58,935 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:58,937 - moleculekit.molecule - INFO - Removed 2 atoms. 93 atoms remaining in the molecule.
# 2022-03-16 16:37:59,072 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:59,074 - moleculekit.molecule - INFO - Removed 3 atoms. 28 atoms remaining in the molecule.
# 2022-03-16 16:37:59,116 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:59,118 - moleculekit.molecule - INFO - Removed 2 atoms. 81 atoms remaining in the molecule.
# 2022-03-16 16:37:59,163 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:59,165 - moleculekit.molecule - INFO - Removed 1 atoms. 67 atoms remaining in the molecule.
# 2022-03-16 16:37:59,336 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:59,337 - moleculekit.molecule - INFO - Removed 5 atoms. 49 atoms remaining in the molecule.
# 2022-03-16 16:37:59,424 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:59,425 - moleculekit.molecule - INFO - Removed 2 atoms. 55 atoms remaining in the molecule.
# 2022-03-16 16:37:59,765 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:37:59,767 - moleculekit.molecule - INFO - Removed 2 atoms. 67 atoms remaining in the molecule.
# 2022-03-16 16:38:00,030 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,031 - moleculekit.molecule - INFO - Removed 1 atoms. 94 atoms remaining in the molecule.
# 2022-03-16 16:38:00,116 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,118 - moleculekit.molecule - INFO - Removed 1 atoms. 32 atoms remaining in the molecule.
# 2022-03-16 16:38:00,160 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,162 - moleculekit.molecule - INFO - Removed 2 atoms. 79 atoms remaining in the molecule.
# 2022-03-16 16:38:00,291 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,292 - moleculekit.molecule - INFO - Removed 1 atoms. 71 atoms remaining in the molecule.
# 2022-03-16 16:38:00,382 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,383 - moleculekit.molecule - INFO - Removed 1 atoms. 30 atoms remaining in the molecule.
# 2022-03-16 16:38:00,425 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,426 - moleculekit.molecule - INFO - Removed 10 atoms. 64 atoms remaining in the molecule.
# 2022-03-16 16:38:00,555 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,556 - moleculekit.molecule - INFO - Removed 1 atoms. 60 atoms remaining in the molecule.
# 2022-03-16 16:38:00,601 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,603 - moleculekit.molecule - INFO - Removed 1 atoms. 33 atoms remaining in the molecule.
# 2022-03-16 16:38:00,743 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,744 - moleculekit.molecule - INFO - Removed 1 atoms. 32 atoms remaining in the molecule.
# 2022-03-16 16:38:00,829 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,832 - moleculekit.molecule - INFO - Removed 5 atoms. 92 atoms remaining in the molecule.
# 2022-03-16 16:38:00,894 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:00,896 - moleculekit.molecule - INFO - Removed 1 atoms. 87 atoms remaining in the molecule.
# 2022-03-16 16:38:01,028 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:01,030 - moleculekit.molecule - INFO - Removed 10 atoms. 83 atoms remaining in the molecule.
# 2022-03-16 16:38:01,115 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:01,116 - moleculekit.molecule - INFO - Removed 3 atoms. 88 atoms remaining in the molecule.
# 2022-03-16 16:38:01,160 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:01,162 - moleculekit.molecule - INFO - Removed 3 atoms. 80 atoms remaining in the molecule.
# 2022-03-16 16:38:01,229 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:01,230 - moleculekit.molecule - INFO - Removed 2 atoms. 78 atoms remaining in the molecule.
# 2022-03-16 16:38:01,373 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:01,374 - moleculekit.molecule - INFO - Removed 5 atoms. 86 atoms remaining in the molecule.
# 2022-03-16 16:38:01,455 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:01,456 - moleculekit.molecule - INFO - Removed 1 atoms. 33 atoms remaining in the molecule.
# 2022-03-16 16:38:01,539 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:01,541 - moleculekit.molecule - INFO - Removed 3 atoms. 68 atoms remaining in the molecule.
# 2022-03-16 16:38:01,682 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:01,684 - moleculekit.molecule - INFO - Removed 1 atoms. 71 atoms remaining in the molecule.
# 2022-03-16 16:38:02,021 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:02,023 - moleculekit.molecule - INFO - Removed 2 atoms. 64 atoms remaining in the molecule.
# 2022-03-16 16:38:02,121 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:02,123 - moleculekit.molecule - INFO - Removed 3 atoms. 81 atoms remaining in the molecule.
# 2022-03-16 16:38:02,250 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:02,252 - moleculekit.molecule - INFO - Removed 1 atoms. 79 atoms remaining in the molecule.
# 2022-03-16 16:38:02,336 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:02,338 - moleculekit.molecule - INFO - Removed 1 atoms. 30 atoms remaining in the molecule.
# 2022-03-16 16:38:02,509 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:02,511 - moleculekit.molecule - INFO - Removed 5 atoms. 80 atoms remaining in the molecule.
# 2022-03-16 16:38:02,556 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:02,558 - moleculekit.molecule - INFO - Removed 4 atoms. 83 atoms remaining in the molecule.
# 2022-03-16 16:38:02,645 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:02,646 - moleculekit.molecule - INFO - Removed 1 atoms. 54 atoms remaining in the molecule.
# 2022-03-16 16:38:02,855 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:02,857 - moleculekit.molecule - INFO - Removed 1 atoms. 87 atoms remaining in the molecule.
# 2022-03-16 16:38:02,940 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:02,942 - moleculekit.molecule - INFO - Removed 2 atoms. 96 atoms remaining in the molecule.
# 2022-03-16 16:38:03,234 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:03,236 - moleculekit.molecule - INFO - Removed 1 atoms. 22 atoms remaining in the molecule.
# 2022-03-16 16:38:03,276 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:03,278 - moleculekit.molecule - INFO - Removed 2 atoms. 29 atoms remaining in the molecule.
# 2022-03-16 16:38:03,364 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:03,366 - moleculekit.molecule - INFO - Removed 1 atoms. 88 atoms remaining in the molecule.
# 2022-03-16 16:38:03,410 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:03,412 - moleculekit.molecule - INFO - Removed 1 atoms. 49 atoms remaining in the molecule.
# 2022-03-16 16:38:03,618 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:03,620 - moleculekit.molecule - INFO - Removed 1 atoms. 24 atoms remaining in the molecule.
# 2022-03-16 16:38:03,746 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:03,748 - moleculekit.molecule - INFO - Removed 7 atoms. 76 atoms remaining in the molecule.
# 2022-03-16 16:38:03,835 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:03,836 - moleculekit.molecule - INFO - Removed 1 atoms. 87 atoms remaining in the molecule.
# 2022-03-16 16:38:03,923 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:03,924 - moleculekit.molecule - INFO - Removed 12 atoms. 74 atoms remaining in the molecule.
# 2022-03-16 16:38:04,092 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:04,093 - moleculekit.molecule - INFO - Removed 2 atoms. 38 atoms remaining in the molecule.
# 2022-03-16 16:38:04,465 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:04,467 - moleculekit.molecule - INFO - Removed 3 atoms. 66 atoms remaining in the molecule.
# 2022-03-16 16:38:04,512 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:04,513 - moleculekit.molecule - INFO - Removed 8 atoms. 62 atoms remaining in the molecule.
# 2022-03-16 16:38:04,515 - moleculekit.molecule - INFO - Removed 2 atoms. 60 atoms remaining in the molecule.
# 2022-03-16 16:38:04,557 - moleculekit.molecule - WARNING - Alternative atom locations detected. Only altloc A was kept. If you prefer to keep all use the keepaltloc="all" option when reading the file.
# 2022-03-16 16:38:04,559 - moleculekit.molecule - INFO - Removed 1 atoms. 30 atoms remaining in the molecule.
